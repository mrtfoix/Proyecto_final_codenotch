# %% [markdown]
# #### Consideraciones:
# - El dataset de ```poca_antelacion``` no puede incluir la columna ```lead_time``` en el modelo de Machine Learning, porque podríamos engañarlo, ya que de la manera que lo hemos creado todos los que tengan un ```lead_time``` mayor a 15 van a ser cancelaciones y no tiene porque ser así.

# %% [markdown]
# #### Posibles modelos de clasificacion a utilizar:
# - Utilizar la libreria Lazypredict

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
reservas = pd.read_csv("Data/hotel_bookings_clean.csv")
meteo_algarve = pd.read_csv("Data/meteo_algarve_clean.csv")
meteo_lisboa = pd.read_csv("Data/meteo_lisboa_clean.csv")
reservas['arrival_date'] = pd.to_datetime(reservas['arrival_date'])
reservas['reservation_status_date'] = pd.to_datetime(reservas['reservation_status_date'])
reservas['children'] = reservas['children'].astype(int)

# %%
mucha_antelacion = reservas[((reservas["is_canceled"] == 1) &
                             (reservas['arrival_date'] - reservas['reservation_status_date'] > pd.Timedelta(days=15)) |
                             ((reservas["is_canceled"] == 0) &
                              (reservas['lead_time'] > 15)))]
poca_antelacion = reservas[((reservas["is_canceled"] == 1) &
                            (reservas['arrival_date'] - reservas['reservation_status_date'] <= pd.Timedelta(days=15)) |
                            ((reservas["is_canceled"] == 0) &
                             (reservas['lead_time'] <= 15)))]
poca_antelacion.drop(columns='lead_time', inplace=True)
# Out:
# C:\Users\mrtfo\AppData\Local\Temp\ipykernel_27024\4046048785.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   poca_antelacion.drop(columns='lead_time', inplace=True)

# %% [markdown]
# ### Fechas expresadas en ángulos

# %% [markdown]
# Crearemos dos _features_ nuevas con los dias del año expresados en "Coordenadas Polares", en el que cada día está expresado por un ángulo entre $0$ y $360$ grados, aunque aquí lo expresaremos en radianes, de $0$ a $2\pi$. Una _feature_ será el coseno ($\cos$) del ángulo y la otra el seno ($\sin$). De esa forma habrá la misma distancia entre, por ejemplo, el 30 de enero y el 31 que entre el 31 de enero y el 1 de febrero.

# %%
mucha_antelacion['arrival_date_year'] = mucha_antelacion['arrival_date'].dt.year
mucha_antelacion['arrival_date_day/month'] = mucha_antelacion['arrival_date'].dt.strftime('%d/%m')
# Out:
# C:\Users\mrtfo\AppData\Local\Temp\ipykernel_27024\3512363893.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   mucha_antelacion['arrival_date_year'] = mucha_antelacion['arrival_date'].dt.year
# C:\Users\mrtfo\AppData\Local\Temp\ipykernel_27024\3512363893.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   mucha_antelacion['arrival_date_day/month'] = mucha_antelacion['arrival_date'].dt.strftime('%d/%m')

# %%
dias_por_mes_1 = [
    31, 28, 31, 30, 31, 30, 31, 31, 30, 31, 30, 31
]
dias_por_mes_2 = [
    31, 29, 31, 30, 31, 30, 31, 31, 30, 31, 30, 31
]

# %%
# Creamos una función que nos devuelva el numero de día del año, teniendo en cuenta el año bisiesto de nuestro período de 
# estudio, concretamente el año 2016. 

def dia_del_año(dia_mes, anio): 
    dia, mes = dia_mes.split('/')
    dia = int(dia)
    mes = int(mes)
    if anio%4 == 0: 
        return dia + sum(dias_por_mes_2[:mes-1])
    else:
        return dia + sum(dias_por_mes_1[:mes-1])

# %%
dias_mes = list(mucha_antelacion['arrival_date_day/month'])
anios = list(mucha_antelacion['arrival_date_year'])

# %%
# Pasamos el número de día a ángulo y calculamos seno y coseno. 

dias_x = []
dias_y = []
for dia, anio in zip(dias_mes,anios):
    if anio%4 == 0:
        angulo = 2*np.pi * dia_del_año(dia,anio)/366
        dias_x.append(np.cos(angulo))
        dias_y.append(np.sin(angulo))
    else:
        angulo = 2*np.pi * dia_del_año(dia,anio)/365
        dias_x.append(np.cos(angulo))
        dias_y.append(np.sin(angulo))

# %%
# Añadimos las nuevas columnas calculadas y quitamos las que hemos creado para calcularlas. 

mucha_antelacion['dia_x'] = dias_x
mucha_antelacion['dia_y'] = dias_y
mucha_antelacion.drop(columns=["arrival_date_day/month","arrival_date_year"],inplace=True)
# Out:
# C:\Users\mrtfo\AppData\Local\Temp\ipykernel_27024\3388695010.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   mucha_antelacion['dia_x'] = dias_x
# C:\Users\mrtfo\AppData\Local\Temp\ipykernel_27024\3388695010.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   mucha_antelacion['dia_y'] = dias_y
# C:\Users\mrtfo\AppData\Local\Temp\ipykernel_27024\3388695010.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   mucha_antelacion.drop(columns=["arrival_date_day/month","arrival_date_year"],inplace=True)

# %%
mucha_antelacion[["dia_x","dia_y"]]
# Out:
#            dia_x     dia_y
# 0      -0.999963  0.008607
# 1      -0.999963  0.008607
# 8      -0.999963  0.008607
# 9      -0.999963  0.008607
# 11     -0.999963  0.008607
# ...          ...       ...
# 118893 -0.519744 -0.854322
# 118894 -0.504961 -0.863142
# 118895 -0.504961 -0.863142
# 118896 -0.504961 -0.863142
# 118897 -0.534373 -0.845249
#
# [85073 rows x 2 columns]

# %% [markdown]
# # Más de 15 dias

# %%
# Hacemos One-hot-encoding con las variables categóricas que tenemos.

mucha_antelacion = pd.get_dummies(mucha_antelacion)
mucha_antelacion.iloc[0], mucha_antelacion.shape
# Out:
# (is_canceled                                         0
#  lead_time                                         342
#  stays_in_weekend_nights                             0
#  stays_in_week_nights                                0
#  adults                                              2
#  children                                            0
#  babies                                              0
#  is_repeated_guest                                   0
#  previous_cancellations                              0
#  previous_bookings_not_canceled                      0
#  booking_changes                                     3
#  days_in_waiting_list                                0
#  total_of_special_requests                           0
#  reservation_status_date           2015-07-01 00:00:00
#  arrival_date                      2015-07-01 00:00:00
#  dia_x                                       -0.999963
#  dia_y                                        0.008607
#  hotel_City Hotel                                    0
#  hotel_Resort Hotel                                  1
#  meal_BB                                             1
#  meal_FB                                             0
#  meal_HB                                             0
#  meal_No_meal                                        0
#  country_DEU                                         0
#  country_ESP                                         0
#  country_FRA                                         0
#  country_GBR                                         0
#  country_PRT                                         1
#  country_otros                                       0
#  market_segment_Aviation                             0
#  market_segment_Complementary                        0
#  market_segment_Corporate                            0
#  market_segment_Direct                               1
#  market_segment_Groups                               0
#  market_segment_TA/TO                                0
#  distribution_channel_Corporate                      0
#  distribution_channel_Direct                         1
#  distribution_channel_GDS                            0
#  distribution_channel_TA/TO                          0
#  deposit_type_No Deposit                             1
#  deposit_type_Non Refund                             0
#  deposit_type_Refundable                             0
#  customer_type_Contract                              0
#  customer_type_Group                                 0
#  customer_type_Transient                             1
#  customer_type_Transient-Party                       0
#  Name: 0, dtype: object,
#  (85073, 46))

# %%
# Solo necesito un tipo de Hotel, ya que al ser solo dos opciones, si no es Urbano significa que es Resort y viceversa.
# Pasa lo mismo con todas las categorías. Si son todas 0 significa que es la que he excluido. Por lo que podemos quedarnos 
# con todas las características menos una.  
# "Reservation_status_date" nos da información posterior a la posible cancelación, por lo que no nos sirve para la predicción
# y por tanto la eliminamos. 

features = [
    "lead_time",
    "stays_in_weekend_nights",
    "stays_in_week_nights",
    "adults",
    "children",
    "babies",
    "is_repeated_guest",
    "previous_cancellations",
    "previous_bookings_not_canceled",
    "booking_changes",
    "days_in_waiting_list",
    "total_of_special_requests",
    "dia_x",
    "dia_y",
    "hotel_City Hotel",
    "meal_BB",
    "meal_FB",
    "meal_HB",
    "country_DEU",
    "country_ESP",
    "country_FRA",
    "country_GBR",
    "country_PRT",
    "market_segment_Aviation",
    "market_segment_Corporate",
    "market_segment_Direct",
    "market_segment_Groups",
    "market_segment_TA/TO",
    "distribution_channel_Corporate",
    "distribution_channel_Direct",
    "distribution_channel_TA/TO",
    "deposit_type_Non Refund",
    "deposit_type_Refundable",
    "customer_type_Contract",
    "customer_type_Group",
    "customer_type_Transient"
]

# %%
# Separamos los datos train y test por fecha. 
# Usaremos los datos desde el 1 de julio del 2015 hasta el 30 de junio del 2017 para predecir los dos meses de verano del 2017, 
# concretamente, desde el 1 de julio al 31 de agosto. 

X = mucha_antelacion[features]
y = mucha_antelacion['is_canceled']
train_data = mucha_antelacion[(mucha_antelacion['arrival_date'] >= pd.Timestamp('2015-07-01')) & 
                              (mucha_antelacion['arrival_date'] <= pd.Timestamp('2017-06-30'))]
test_data = mucha_antelacion[(mucha_antelacion['arrival_date'] >= pd.Timestamp('2017-07-01')) & 
                             (mucha_antelacion['arrival_date'] <= pd.Timestamp('2017-08-31'))]
# Balancear los datos
#Contar la frecuencia de cada clase y obtener la frecuencia mínima entre las clases
frecuencia_minima = train_data['is_canceled'].value_counts().min()

#Crear una muestra ponderada según la frecuencia de la clase minoritaria
train_data = train_data.groupby('is_canceled').apply(lambda x: x.sample(frac=frecuencia_minima / len(x))).reset_index(drop=True)

X_train = train_data[features]
y_train = train_data['is_canceled']
X_test = test_data[features]
y_test = test_data['is_canceled']
print(X_train.shape, y_train.shape, X_test.shape, y_test.shape)
# Out:
# (61498, 36) (61498,) (8356, 36) (8356,)

# %%
# Escalar los datos

from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
scaler.fit(X_train)
X_train_sc = scaler.transform(X_train)
X_test_sc = scaler.transform(X_test)

# %%
df_train_sc = pd.DataFrame(X_train_sc, columns=X_train.columns)
df_test_sc = pd.DataFrame(X_test_sc, columns=X_test.columns)

# %% [markdown]
# ### Feature importance

# %%
import xgboost as xgb

# Vamos a usar un método embebido que nos informe de la importancia de las características.
# Crea un modelo XGBoost Classifier.

model = xgb.XGBClassifier()

# Entrenamos el modelo en los datos asignados.

model.fit(X_train_sc, y_train)

# Calculamos la importancia de las características

feature_importances = model.feature_importances_

# Asociamos las importancias con los nombres de las características.

feature_names = X.columns
feature_importance_dict = dict(zip(feature_names, feature_importances))

# Ordenamos las características por importancia (de mayor a menor)

sorted_feature_importance = dict(sorted(feature_importance_dict.items(), key=lambda x: x[1], reverse=True))

# Aquí imprimimos la importancia de las características.
# (número adimensional, las características se comparan entre sí en términos de su contribución relativa a la predicción).

for feature, importance in sorted_feature_importance.items():
    print(f'Feature: {feature}, Importance: {importance}')
# Out:
# Feature: deposit_type_Non Refund, Importance: 0.7117108702659607
# Feature: previous_cancellations, Importance: 0.046180758625268936
# Feature: customer_type_Transient, Importance: 0.03400471433997154
# Feature: country_PRT, Importance: 0.0277231577783823
# Feature: market_segment_TA/TO, Importance: 0.026189379394054413
# Feature: total_of_special_requests, Importance: 0.01590176299214363
# Feature: distribution_channel_Direct, Importance: 0.014860829338431358
# Feature: country_DEU, Importance: 0.00942200981080532
# Feature: country_FRA, Importance: 0.008897603489458561
# Feature: booking_changes, Importance: 0.007934418506920338
# Feature: hotel_City Hotel, Importance: 0.00775158079341054
# Feature: children, Importance: 0.006741322576999664
# Feature: previous_bookings_not_canceled, Importance: 0.0066783917136490345
# Feature: customer_type_Contract, Importance: 0.005700566340237856
# Feature: country_GBR, Importance: 0.005589665379375219
# Feature: meal_HB, Importance: 0.0054931314662098885
# Feature: market_segment_Groups, Importance: 0.004722411744296551
# Feature: lead_time, Importance: 0.004693496506661177
# Feature: market_segment_Direct, Importance: 0.004154846537858248
# Feature: stays_in_week_nights, Importance: 0.004098677076399326
# Feature: distribution_channel_Corporate, Importance: 0.0034775238018482924
# Feature: meal_FB, Importance: 0.0033700682688504457
# Feature: adults, Importance: 0.003355456981807947
# Feature: country_ESP, Importance: 0.003321845317259431
# Feature: dia_y, Importance: 0.0033124294131994247
# Feature: meal_BB, Importance: 0.0032385820522904396
# Feature: dia_x, Importance: 0.0032298348378390074
# Feature: babies, Importance: 0.00304853031411767
# Feature: stays_in_weekend_nights, Importance: 0.002982579404488206
# Feature: is_repeated_guest, Importance: 0.0027900885324925184
# Feature: days_in_waiting_list, Importance: 0.0027291239239275455
# Feature: distribution_channel_TA/TO, Importance: 0.0024874380324035883
# Feature: market_segment_Corporate, Importance: 0.0021518636494874954
# Feature: customer_type_Group, Importance: 0.0016549471765756607
# Feature: market_segment_Aviation, Importance: 0.00040014355909079313
# Feature: deposit_type_Refundable, Importance: 0.0

# %% [markdown]
# ### Correlación entre variables

# %%
df = df_train_sc[features]
df['is_canceled'] = y_train
corr = df.corr()

# %%
corr[corr.is_canceled.abs()<0.02].index
# Out:
# Index(['adults', 'children', 'is_repeated_guest', 'dia_y',
#        'market_segment_Aviation'],
#       dtype='object')

# %%
# Eliminamos todas las variables cuya correlación con la variable a predecir es menor del 2%. 
# También hemos eliminado las 3 variables menos importantes según el método usado anteriormente.

# %%
features_2 = [
    "lead_time",
    "stays_in_weekend_nights",
    "stays_in_week_nights",
    "babies",
    "previous_cancellations",
    "previous_bookings_not_canceled",
    "booking_changes",
    "days_in_waiting_list",
    "total_of_special_requests",
    "hotel_City Hotel",
    "meal_BB",
    "meal_FB",
    "meal_HB",
    "country_DEU",
    "country_ESP",
    "country_FRA",
    "country_GBR",
    "country_PRT",
    "market_segment_Corporate",
    "market_segment_Direct",
    "market_segment_Groups",
    "market_segment_TA/TO",
    "distribution_channel_Corporate",
    "distribution_channel_Direct",
    "distribution_channel_TA/TO",
    "deposit_type_Non Refund",
    "customer_type_Contract",
    "customer_type_Transient"
]

# %%
# Creamos una matriz de correlación para visualizar la multicolinealidad entre variables y comprobar si hay variables 
# que nos den prácticamnte la misma información.

df = df_train_sc[features_2]
df['is_canceled'] = y_train
corr = df.corr()
corr.style.background_gradient(cmap='coolwarm').format(precision=3)
# Out:
# C:\Users\mrtfo\AppData\Local\Temp\ipykernel_27024\824592789.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['is_canceled'] = y_train
# <style type="text/css">
# #T_ec98c_row0_col0, #T_ec98c_row1_col1, #T_ec98c_row2_col2, #T_ec98c_row3_col3, #T_ec98c_row4_col4, #T_ec98c_row5_col5, #T_ec98c_row6_col6, #T_ec98c_row7_col7, #T_ec98c_row8_col8, #T_ec98c_row9_col9, #T_ec98c_row10_col10, #T_ec98c_row11_col11, #T_ec98c_row12_col12, #T_ec98c_row13_col13, #T_ec98c_row14_col14, #T_ec98c_row15_col15, #T_ec98c_row16_col16, #T_ec98c_row17_col17, #T_ec98c_row18_col18, #T_ec98c_row19_col19, #T_ec98c_row20_col20, #T_ec98c_row21_col21, #T_ec98c_row22_col22, #T_ec98c_row23_col23, #T_ec98c_row24_col24, #T_ec98c_row25_col25, #T_ec98c_row26_col26, #T_ec98c_row27_col27, #T_ec98c_row28_col28 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_ec98c_row0_col1, #T_ec98c_row0_col13, #T_ec98c_row1_col13, #T_ec98c_row6_col13, #T_ec98c_row6_col14, #T_ec98c_row12_col6, #T_ec98c_row12_col28, #T_ec98c_row17_col11, #T_ec98c_row19_col14, #T_ec98c_row22_col1, #T_ec98c_row22_col8, #T_ec98c_row24_col16, #T_ec98c_row25_col7 {
#   background-color: #799cf8;
#   color: #f1f1f1;
# }
# #T_ec98c_row0_col2, #T_ec98c_row1_col27, #T_ec98c_row4_col26, #T_ec98c_row5_col8, #T_ec98c_row6_col1, #T_ec98c_row8_col16, #T_ec98c_row8_col20, #T_ec98c_row12_col17, #T_ec98c_row24_col0, #T_ec98c_row27_col9 {
#   background-color: #97b8ff;
#   color: #000000;
# }
# #T_ec98c_row0_col3 {
#   background-color: #465ecf;
#   color: #f1f1f1;
# }
# #T_ec98c_row0_col4, #T_ec98c_row1_col28, #T_ec98c_row7_col13, #T_ec98c_row14_col6, #T_ec98c_row17_col2, #T_ec98c_row18_col1 {
#   background-color: #7295f4;
#   color: #f1f1f1;
# }
# #T_ec98c_row0_col5, #T_ec98c_row2_col5, #T_ec98c_row3_col4, #T_ec98c_row9_col6, #T_ec98c_row11_col7, #T_ec98c_row21_col3 {
#   background-color: #506bda;
#   color: #f1f1f1;
# }
# #T_ec98c_row0_col6, #T_ec98c_row1_col25, #T_ec98c_row7_col11, #T_ec98c_row14_col13, #T_ec98c_row18_col11, #T_ec98c_row20_col6, #T_ec98c_row23_col0, #T_ec98c_row23_col28, #T_ec98c_row26_col6 {
#   background-color: #6485ec;
#   color: #f1f1f1;
# }
# #T_ec98c_row0_col7, #T_ec98c_row2_col18, #T_ec98c_row4_col9, #T_ec98c_row11_col1, #T_ec98c_row12_col8, #T_ec98c_row14_col2, #T_ec98c_row16_col18, #T_ec98c_row18_col2, #T_ec98c_row23_col18, #T_ec98c_row24_col2 {
#   background-color: #88abfd;
#   color: #000000;
# }
# #T_ec98c_row0_col8, #T_ec98c_row10_col6, #T_ec98c_row17_col5, #T_ec98c_row20_col1, #T_ec98c_row21_col6, #T_ec98c_row26_col11, #T_ec98c_row28_col7 {
#   background-color: #6384eb;
#   color: #f1f1f1;
# }
# #T_ec98c_row0_col9, #T_ec98c_row6_col18, #T_ec98c_row11_col17, #T_ec98c_row19_col8, #T_ec98c_row24_col26, #T_ec98c_row26_col1 {
#   background-color: #9ebeff;
#   color: #000000;
# }
# #T_ec98c_row0_col10, #T_ec98c_row3_col24, #T_ec98c_row4_col23, #T_ec98c_row6_col21, #T_ec98c_row7_col23, #T_ec98c_row9_col25, #T_ec98c_row10_col24, #T_ec98c_row13_col23, #T_ec98c_row14_col20, #T_ec98c_row18_col23, #T_ec98c_row26_col10 {
#   background-color: #cbd8ee;
#   color: #000000;
# }
# #T_ec98c_row0_col11, #T_ec98c_row0_col27, #T_ec98c_row1_col17, #T_ec98c_row5_col11, #T_ec98c_row21_col28, #T_ec98c_row22_col4 {
#   background-color: #6788ee;
#   color: #f1f1f1;
# }
# #T_ec98c_row0_col12, #T_ec98c_row3_col21, #T_ec98c_row6_col19, #T_ec98c_row8_col23, #T_ec98c_row14_col23, #T_ec98c_row22_col10, #T_ec98c_row27_col19 {
#   background-color: #d2dbe8;
#   color: #000000;
# }
# #T_ec98c_row0_col14, #T_ec98c_row15_col3, #T_ec98c_row15_col17, #T_ec98c_row17_col6, #T_ec98c_row21_col11, #T_ec98c_row23_col7, #T_ec98c_row28_col13 {
#   background-color: #4c66d6;
#   color: #f1f1f1;
# }
# #T_ec98c_row0_col15, #T_ec98c_row6_col5, #T_ec98c_row8_col5, #T_ec98c_row18_col0, #T_ec98c_row19_col0 {
#   background-color: #5f7fe8;
#   color: #f1f1f1;
# }
# #T_ec98c_row0_col16, #T_ec98c_row2_col6, #T_ec98c_row9_col0, #T_ec98c_row11_col26, #T_ec98c_row12_col16, #T_ec98c_row13_col18, #T_ec98c_row20_col11, #T_ec98c_row22_col2, #T_ec98c_row25_col21, #T_ec98c_row26_col18 {
#   background-color: #89acfd;
#   color: #000000;
# }
# #T_ec98c_row0_col17, #T_ec98c_row0_col28, #T_ec98c_row1_col24, #T_ec98c_row3_col19, #T_ec98c_row5_col20, #T_ec98c_row6_col12, #T_ec98c_row8_col19, #T_ec98c_row15_col23, #T_ec98c_row17_col24 {
#   background-color: #cedaeb;
#   color: #000000;
# }
# #T_ec98c_row0_col18, #T_ec98c_row2_col13, #T_ec98c_row4_col15, #T_ec98c_row5_col0, #T_ec98c_row6_col0, #T_ec98c_row13_col25, #T_ec98c_row14_col28, #T_ec98c_row17_col4, #T_ec98c_row21_col22 {
#   background-color: #7597f6;
#   color: #f1f1f1;
# }
# #T_ec98c_row0_col19, #T_ec98c_row9_col19, #T_ec98c_row10_col9, #T_ec98c_row10_col25 {
#   background-color: #b1cbfc;
#   color: #000000;
# }
# #T_ec98c_row0_col20, #T_ec98c_row17_col20 {
#   background-color: #f7bca1;
#   color: #000000;
# }
# #T_ec98c_row0_col21, #T_ec98c_row1_col22, #T_ec98c_row2_col8, #T_ec98c_row6_col8, #T_ec98c_row13_col9, #T_ec98c_row27_col12 {
#   background-color: #a3c2fe;
#   color: #000000;
# }
# #T_ec98c_row0_col22, #T_ec98c_row10_col17, #T_ec98c_row10_col18, #T_ec98c_row10_col27, #T_ec98c_row19_col2, #T_ec98c_row21_col1, #T_ec98c_row23_col2, #T_ec98c_row23_col22, #T_ec98c_row28_col22 {
#   background-color: #a2c1ff;
#   color: #000000;
# }
# #T_ec98c_row0_col23, #T_ec98c_row4_col21, #T_ec98c_row8_col12, #T_ec98c_row13_col19, #T_ec98c_row15_col12, #T_ec98c_row17_col0, #T_ec98c_row24_col9, #T_ec98c_row24_col10, #T_ec98c_row25_col12 {
#   background-color: #c1d4f4;
#   color: #000000;
# }
# #T_ec98c_row0_col24, #T_ec98c_row25_col0 {
#   background-color: #dedcdb;
#   color: #000000;
# }
# #T_ec98c_row0_col25, #T_ec98c_row9_col24 {
#   background-color: #ead4c8;
#   color: #000000;
# }
# #T_ec98c_row0_col26, #T_ec98c_row8_col2, #T_ec98c_row15_col8, #T_ec98c_row18_col17, #T_ec98c_row19_col22, #T_ec98c_row22_col21 {
#   background-color: #a5c3fe;
#   color: #000000;
# }
# #T_ec98c_row1_col0, #T_ec98c_row4_col5, #T_ec98c_row6_col25, #T_ec98c_row9_col7, #T_ec98c_row11_col9, #T_ec98c_row11_col13, #T_ec98c_row13_col6, #T_ec98c_row14_col16, #T_ec98c_row18_col13, #T_ec98c_row22_col0, #T_ec98c_row22_col11, #T_ec98c_row22_col13 {
#   background-color: #6f92f3;
#   color: #f1f1f1;
# }
# #T_ec98c_row1_col2 {
#   background-color: #f5c4ac;
#   color: #000000;
# }
# #T_ec98c_row1_col3, #T_ec98c_row4_col7, #T_ec98c_row5_col7, #T_ec98c_row9_col5, #T_ec98c_row13_col17, #T_ec98c_row14_col0, #T_ec98c_row24_col11, #T_ec98c_row25_col14, #T_ec98c_row27_col0 {
#   background-color: #5572df;
#   color: #f1f1f1;
# }
# #T_ec98c_row1_col4, #T_ec98c_row2_col7, #T_ec98c_row8_col0, #T_ec98c_row9_col16, #T_ec98c_row19_col24, #T_ec98c_row22_col7, #T_ec98c_row24_col4, #T_ec98c_row27_col6, #T_ec98c_row28_col5 {
#   background-color: #4e68d8;
#   color: #f1f1f1;
# }
# #T_ec98c_row1_col5, #T_ec98c_row7_col4, #T_ec98c_row11_col3, #T_ec98c_row15_col7, #T_ec98c_row25_col15, #T_ec98c_row27_col3 {
#   background-color: #536edd;
#   color: #f1f1f1;
# }
# #T_ec98c_row1_col6, #T_ec98c_row1_col15, #T_ec98c_row5_col1, #T_ec98c_row5_col28, #T_ec98c_row6_col15, #T_ec98c_row8_col14, #T_ec98c_row13_col27, #T_ec98c_row14_col9, #T_ec98c_row19_col26, #T_ec98c_row24_col13, #T_ec98c_row26_col9, #T_ec98c_row26_col28, #T_ec98c_row28_col2 {
#   background-color: #81a4fb;
#   color: #f1f1f1;
# }
# #T_ec98c_row1_col7 {
#   background-color: #3e51c5;
#   color: #f1f1f1;
# }
# #T_ec98c_row1_col8, #T_ec98c_row4_col28, #T_ec98c_row7_col0, #T_ec98c_row11_col25, #T_ec98c_row12_col2, #T_ec98c_row28_col19 {
#   background-color: #a9c6fd;
#   color: #000000;
# }
# #T_ec98c_row1_col9, #T_ec98c_row6_col4, #T_ec98c_row7_col3, #T_ec98c_row13_col3, #T_ec98c_row13_col4, #T_ec98c_row17_col8, #T_ec98c_row18_col3, #T_ec98c_row20_col27 {
#   background-color: #4961d2;
#   color: #f1f1f1;
# }
# #T_ec98c_row1_col10, #T_ec98c_row1_col20, #T_ec98c_row4_col22, #T_ec98c_row6_col24, #T_ec98c_row10_col22, #T_ec98c_row14_col10, #T_ec98c_row15_col20, #T_ec98c_row28_col12, #T_ec98c_row28_col21 {
#   background-color: #bbd1f8;
#   color: #000000;
# }
# #T_ec98c_row1_col11, #T_ec98c_row2_col25, #T_ec98c_row11_col6, #T_ec98c_row16_col25, #T_ec98c_row20_col2, #T_ec98c_row20_col7, #T_ec98c_row22_col14, #T_ec98c_row22_col27, #T_ec98c_row26_col13, #T_ec98c_row28_col1 {
#   background-color: #6c8ff1;
#   color: #f1f1f1;
# }
# #T_ec98c_row1_col12, #T_ec98c_row1_col23, #T_ec98c_row8_col24, #T_ec98c_row10_col20, #T_ec98c_row16_

# %% [markdown]
# ### Valor de Inflación de la Varianza (VIF)

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor

# %%
# Calculamos el VIF para estudiar la multicolinealidad, con la ayuda de la matriz de correlación.

df = df_train_sc[features_2]
df['is_canceled'] = y_train
corr = df.corr()
# vif_data = pd.DataFrame()
# vif_data["Variable"] = X.columns
# vif_data["VIF"] = [variance_inflation_factor(X.values, i) for i in range(X.shape[1])]
vif = pd.Series([variance_inflation_factor(corr.values, i) for i in range(corr.shape[1])], index=df.columns)
vif
# vif_data
# Out:
# C:\Users\mrtfo\AppData\Local\Temp\ipykernel_27024\3197725315.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['is_canceled'] = y_train
# lead_time                              4.048319
# stays_in_weekend_nights                3.606840
# stays_in_week_nights                   4.158691
# babies                                 1.175597
# previous_cancellations                 1.473071
# previous_bookings_not_canceled         1.870480
# booking_changes                        1.456166
# days_in_waiting_list                   1.320040
# total_of_special_requests              3.333141
# hotel_City Hotel                       6.230346
# meal_BB                               17.022425
# meal_FB                                2.478912
# meal_HB                               18.615118
# country_DEU                            2.295533
# country_ESP                            2.274081
# country_FRA                            2.518325
# country_GBR                            3.620201
# country_PRT                           22.999156
# market_segment_Corporate           10555.983763
# market_segment_Direct              38419.837739
# market_segment_Groups             151109.465343
# market_segment_TA/TO              201597.238187
# distribution_channel_Corporate     13401.513388
# distribution_channel_Direct        45298.393999
# distribution_channel_TA/TO         65196.777858
# deposit_type_Non Refund               30.000098
# customer_type_Contract                 2.678618
# customer_type_Transient                9.737500
# is_canceled                            8.830191
# dtype: float64

# %%
# Eliminamos las columnas que, a priori, nos dan la misma información que otras:
    # market_segment_Corporate
    # market_segment_Direct
    # market_segment_TA/TO
    
df_2 = df.drop(columns=["distribution_channel_Corporate",
                        "distribution_channel_Direct",
                        "distribution_channel_TA/TO"])
corr = df_2.corr()
vif = pd.Series([variance_inflation_factor(corr.values, i) for i in range(corr.shape[1])], index=df_2.columns)
vif
# Out:
# lead_time                              4.157070
# stays_in_weekend_nights                3.644579
# stays_in_week_nights                   4.094909
# babies                                 1.161660
# previous_cancellations                 1.397826
# previous_bookings_not_canceled         1.944270
# booking_changes                        1.437848
# days_in_waiting_list                   1.312369
# total_of_special_requests              3.091959
# hotel_City Hotel                       4.240015
# meal_BB                               16.681065
# meal_FB                                2.333680
# meal_HB                               18.456000
# country_DEU                            2.285274
# country_ESP                            2.181815
# country_FRA                            2.492228
# country_GBR                            3.511724
# country_PRT                           22.094796
# market_segment_Corporate            6692.581330
# market_segment_Direct              19640.297959
# market_segment_Groups             142560.193778
# market_segment_TA/TO              159365.631623
# deposit_type_Non Refund               29.928243
# customer_type_Contract                 2.453550
# customer_type_Transient                8.804554
# is_canceled                            8.714911
# dtype: float64

# %%
# Eliminando las anteriores features nos quedan las siguentes:

features_3 = [
    "lead_time",
    "stays_in_weekend_nights",
    "stays_in_week_nights",
    "babies",
    "previous_cancellations",
    "previous_bookings_not_canceled",
    "booking_changes",
    "days_in_waiting_list",
    "total_of_special_requests",
    "hotel_City Hotel",
    "meal_BB",
    "meal_FB",
    "meal_HB",
    "country_DEU",
    "country_ESP",
    "country_FRA",
    "country_GBR",
    "country_PRT",
    "market_segment_Corporate",
    "market_segment_Direct",
    "market_segment_Groups",
    "market_segment_TA/TO",
    "deposit_type_Non Refund",
    "customer_type_Contract",
    "customer_type_Transient"
]

# %%
X_train_sc = df_train_sc[features_3]
y_train = train_data['is_canceled']
X_test_sc = df_test_sc[features_3]
y_test = test_data['is_canceled']

# %%
# Comprobamos el P_value para acabar de evaluar la contribución de las variables y eliminamos las features con P_value > 0,05

import statsmodels.api as sm
log_reg = sm.Logit(y_train, X_train_sc).fit()
print(log_reg.summary())
# Out:
# Optimization terminated successfully.
#          Current function value: 0.414369
#          Iterations 9
#                            Logit Regression Results
# ==============================================================================
# Dep. Variable:            is_canceled   No. Observations:                61498
# Model:                          Logit   Df Residuals:                    61473
# Method:                           MLE   Df Model:                           24
# Date:                Mon, 18 Dec 2023   Pseudo R-squ.:                  0.4022
# Time:                        17:12:01   Log-Likelihood:                -25483.
# converged:                       True   LL-Null:                       -42627.
# Covariance Type:            nonrobust   LLR p-value:                     0.000
# ==================================================================================================
#                                      coef    std err          z      P>|z|      [0.025      0.975]
# --------------------------------------------------------------------------------------------------
# lead_time                          0.4853      0.015     32.057      0.000       0.456       0.515
# stays_in_weekend_nights            0.0277      0.013      2.152      0.031       0.002       0.053
# stays_in_week_nights               0.0911      0.013      7.091      0.000       0.066       0.116
# babies                            -0.0025      0.011     -0.224      0.822      -0.025       0.020
# previous_cancellations             1.9636      0.071     27.753      0.000       1.825       2.102
# previous_bookings_not_canceled    -0.4427      0.028    -15.872      0.000      -0.497      -0.388
# booking_changes                   -0.2907      0.015    -18.772      0.000      -0.321      -0.260
# days_in_waiting_list              -0.0720      0.013     -5.427      0.000      -0.098      -0.046
# total_of_special_requests         -0.5568      0.013    -44.316      0.000      -0.581      -0.532
# hotel_City Hotel                   0.1664      0.013     13.051      0.000       0.141       0.191
# meal_BB                           -0.1490      0.015    -10.062      0.000      -0.178      -0.120
# meal_FB                           -0.0300      0.013     -2.329      0.020      -0.055      -0.005
# meal_HB                           -0.1785      0.017    -10.783      0.000      -0.211      -0.146
# country_DEU                       -0.2141      0.012    -17.477      0.000      -0.238      -0.190
# country_ESP                        0.0688      0.011      6.372      0.000       0.048       0.090
# country_FRA                       -0.2040      0.012    -16.905      0.000      -0.228      -0.180
# country_GBR                       -0.1659      0.012    -13.536      0.000      -0.190      -0.142
# country_PRT                        0.6980      0.015     45.239      0.000       0.668       0.728
# market_segment_Corporate           0.2658      0.064      4.155      0.000       0.140       0.391
# market_segment_Direct              0.2760      0.104      2.659      0.008       0.073       0.479
# market_segment_Groups              0.9921      0.194      5.124      0.000       0.613       1.372
# market_segment_TA/TO               1.2524      0.210      5.966      0.000       0.841       1.664
# deposit_type_Non Refund            0.6750      0.021     32.216      0.000       0.634       0.716
# customer_type_Contract             0.0094      0.016      0.600      0.548      -0.021       0.040
# customer_type_Transient            0.8607      0.017     50.704      0.000       0.827       0.894
# ==================================================================================================

# %%
# De esta forma nos quedan estas variables, con las que realizaremos un "Lazy Predict" para escoger el modelo 
# que mejor se ajuste al problema. 

features_4 = [
    "lead_time",
    "stays_in_week_nights",
    "previous_cancellations",
    "previous_bookings_not_canceled",
    "booking_changes",
    "days_in_waiting_list",
    "total_of_special_requests",
    "hotel_City Hotel",
    "meal_BB",
    "meal_HB",
    "country_DEU",
    "country_ESP",
    "country_FRA",
    "country_GBR",
    "country_PRT",
    "market_segment_Corporate",
    "market_segment_Direct",
    "market_segment_Groups",
    "market_segment_TA/TO",
    "deposit_type_Non Refund",
    "customer_type_Transient"
]
print(len(features_4))
# Out:
# 21

# %% [markdown]
# ### Lazy Predict

# %%
from lazypredict.Supervised import LazyClassifier
from sklearn.model_selection import train_test_split


X_train_sc = df_train_sc[features_4]
y_train = train_data['is_canceled']
X_test_sc = df_test_sc[features_4]
y_test = test_data['is_canceled']


# clf = LazyClassifier(verbose=0, ignore_warnings=True, custom_metric=None)
# models, predictions = clf.fit(X_train, X_test, y_train, y_test)

# print(models)

# %%
# Entrenamos el modelo con XGBoost, ya que tiene buena 'Accuracy' y poco tiempo de computacion. 


model = xgb.XGBClassifier()
model.fit(X_train_sc, y_train)
y_pred = model.predict(X_test_sc)

# %%
# Comprovamos los resultados en una matriz de confusion. 

from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay

cm = confusion_matrix(y_test, y_pred)
cm_display = ConfusionMatrixDisplay(cm).plot()

# %% [markdown]
# # 15 dias o menos

# %% [markdown]
# Repetimos el mismo proceso para el dataset con reservas con 15 dias o menos de antelacion.

# %%
# Añadimos los datos meteorologicos al dataset. 
meteo_algarve.rename(columns={'datetime': 'arrival_date'},inplace=True)
meteo_lisboa.rename(columns={'datetime': 'arrival_date'},inplace=True)
meteo_complete = pd.merge(meteo_algarve,meteo_lisboa, how="outer")
meteo_complete["arrival_date"] = pd.to_datetime(meteo_complete["arrival_date"])
poca_antelacion_meteo = pd.merge(poca_antelacion, meteo_complete, on=['hotel','arrival_date'], how='left')

# %%
poca_antelacion_meteo = pd.get_dummies(poca_antelacion_meteo)
poca_antelacion_meteo.iloc[0], poca_antelacion_meteo.shape
# Out:
# (is_canceled                                            0
#  stays_in_weekend_nights                                0
#  stays_in_week_nights                                   1
#  adults                                                 1
#  children                                               0
#  babies                                                 0
#  is_repeated_guest                                      0
#  previous_cancellations                                 0
#  previous_bookings_not_canceled                         0
#  booking_changes                                        0
#  days_in_waiting_list                                   0
#  total_of_special_requests                              0
#  reservation_status_date              2015-07-02 00:00:00
#  arrival_date                         2015-07-01 00:00:00
#  tempmax                                            24.80
#  tempmin                                            17.20
#  temp                                               21.20
#  precip                                              0.00
#  precipprob                                             0
#  windgust                                           54.00
#  windspeed                                          38.30
#  cloudcover                                         35.60
#  hotel_City Hotel                                       0
#  hotel_Resort Hotel                                     1
#  meal_BB                                                1
#  meal_FB                                                0
#  meal_HB                                                0
#  meal_No_meal                                           0
#  country_DEU                                            0
#  country_ESP                                            0
#  country_FRA                                            0
#  country_GBR                                            1
#  country_PRT                                            0
#  country_otros                                          0
#  market_segment_Aviation                                0
#  market_segment_Complementary                           0
#  market_segment_Corporate                               0
#  market_segment_Direct                                  1
#  market_segment_Groups                                  0
#  market_segment_TA/TO                                   0
#  distribution_channel_Corporate                         0
#  distribution_channel_Direct                            1
#  distribution_channel_GDS                               0
#  distribution_channel_TA/TO                             0
#  deposit_type_No Deposit                                1
#  deposit_type_Non Refund                                0
#  deposit_type_Refundable                                0
#  customer_type_Contract                                 0
#  customer_type_Group                                    0
#  customer_type_Transient                                1
#  customer_type_Transient-Party                          0
#  conditions_Clear                                       0
#  conditions_Overcast                                    0
#  conditions_Partially cloudy                            1
#  conditions_Rain                                        0
#  conditions_Rain, Overcast                              0
#  conditions_Rain, Partially cloudy                      0
#  Name: 0, dtype: object,
#  (33825, 57))

# %%
# Partimos de las features que hemos escogido para el modelo de más de 15 dias. 
# Igual que antes, elegimos n-1 categiorias en cada variable categorica. 
# Tambien hemos eliminado lead_time por el motivo explicado al principio del notebook. 
features = [
    "stays_in_week_nights",
    "previous_cancellations",
    "previous_bookings_not_canceled",
    "booking_changes",
    "days_in_waiting_list",
    "total_of_special_requests",
    "hotel_City Hotel",
    "meal_BB",
    "meal_FB",
    "meal_HB",
    "country_DEU",
    "country_ESP",
    "country_FRA",
    "country_GBR",
    "country_PRT",
    "market_segment_Corporate",
    "market_segment_Direct",
    "market_segment_Groups",
    "market_segment_TA/TO",
    "deposit_type_Non Refund",
    "customer_type_Contract",
    "customer_type_Transient",
    "tempmax",
    "tempmin",
    "temp",
    "precip",
    "precipprob",
    "windgust",
    "windspeed",
    "cloudcover",
    "conditions_Clear",
    "conditions_Overcast",
    "conditions_Partially cloudy",
    "conditions_Rain",
    "conditions_Rain, Overcast"
]

# %%
X = poca_antelacion_meteo[features]
y = poca_antelacion_meteo['is_canceled']
train_data = poca_antelacion_meteo[(poca_antelacion_meteo['arrival_date'] >= pd.Timestamp('2015-07-01')) & 
                              (poca_antelacion_meteo['arrival_date'] <= pd.Timestamp('2017-06-30'))]
test_data = poca_antelacion_meteo[(poca_antelacion_meteo['arrival_date'] >= pd.Timestamp('2017-07-01')) & 
                             (poca_antelacion_meteo['arrival_date'] <= pd.Timestamp('2017-08-31'))]
# Balancear los datos
#Contar la frecuencia de cada clase y obtener la frecuencia mínima entre las clases
frecuencia_minima = train_data['is_canceled'].value_counts().min()

#Crear una muestra ponderada según la frecuencia de la clase minoritaria
train_data = train_data.groupby('is_canceled').apply(lambda x: x.sample(frac=frecuencia_minima / len(x))).reset_index(drop=True)

X_train = train_data[features]
y_train = train_data['is_canceled']
X_test = test_data[features]
y_test = test_data['is_canceled']
print(X_train.shape, y_train.shape, X_test.shape, y_test.shape)
# Out:
# (19208, 35) (19208,) (1882, 35) (1882,)

# %%
# Escalar los datos

from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
scaler.fit(X_train)
X_train_sc = scaler.transform(X_train)
X_test_sc = scaler.transform(X_test)

# %%
df_train_sc = pd.DataFrame(X_train_sc, columns=X_train.columns)
df_test_sc = pd.DataFrame(X_test_sc, columns=X_test.columns)

# %%
model = xgb.XGBClassifier()
model.fit(X_train_sc, y_train)
feature_importances = model.feature_importances_
feature_names = X.columns
feature_importance_dict = dict(zip(feature_names, feature_importances))
sorted_feature_importance = dict(sorted(feature_importance_dict.items(), key=lambda x: x[1], reverse=True))
for feature, importance in sorted_feature_importance.items():
    print(f'Feature: {feature}, Importance: {importance}')
# Out:
# Feature: deposit_type_Non Refund, Importance: 0.14213870465755463
# Feature: market_segment_Groups, Importance: 0.13655494153499603
# Feature: previous_cancellations, Importance: 0.09401993453502655
# Feature: hotel_City Hotel, Importance: 0.07557165622711182
# Feature: previous_bookings_not_canceled, Importance: 0.05748375877737999
# Feature: market_segment_TA/TO, Importance: 0.052311621606349945
# Feature: country_PRT, Importance: 0.05147284269332886
# Feature: customer_type_Transient, Importance: 0.03703044354915619
# Feature: meal_HB, Importance: 0.026402555406093597
# Feature: stays_in_week_nights, Importance: 0.02527814358472824
# Feature: customer_type_Contract, Importance: 0.02329300530254841
# Feature: booking_changes, Importance: 0.021804573014378548
# Feature: market_segment_Direct, Importance: 0.021290134638547897
# Feature: days_in_waiting_list, Importance: 0.019040945917367935
# Feature: market_segment_Corporate, Importance: 0.015374679118394852
# Feature: total_of_special_requests, Importance: 0.015243417583405972
# Feature: country_DEU, Importance: 0.014586002565920353
# Feature: country_FRA, Importance: 0.013799240812659264
# Feature: temp, Importance: 0.012859493494033813
# Feature: tempmin, Importance: 0.012759076431393623
# Feature: windgust, Importance: 0.012634310871362686
# Feature: tempmax, Importance: 0.01253447588533163
# Feature: precip, Importance: 0.01242899615317583
# Feature: meal_FB, Importance: 0.011962992139160633
# Feature: windspeed, Importance: 0.011607029475271702
# Feature: cloudcover, Importance: 0.010564394295215607
# Feature: conditions_Partially cloudy, Importance: 0.009273148141801357
# Feature: conditions_Rain, Overcast, Importance: 0.008736382238566875
# Feature: country_ESP, Importance: 0.008617177605628967
# Feature: country_GBR, Importance: 0.008460696786642075
# Feature: meal_BB, Importance: 0.008337394334375858
# Feature: conditions_Rain, Importance: 0.00699262460693717
# Feature: conditions_Clear, Importance: 0.005832103081047535
# Feature: conditions_Overcast, Importance: 0.0037030898965895176
# Feature: precipprob, Importance: 0.0

# %%
df = df_train_sc[features]
df['is_canceled'] = y_train
corr = df.corr()

# %%
corr[corr.is_canceled.abs()<0.02].index
# Out:
# Index(['customer_type_Contract', 'precip', 'precipprob', 'windspeed',
#        'cloudcover', 'conditions_Overcast', 'conditions_Rain',
#        'conditions_Rain, Overcast'],
#       dtype='object')

# %%
features_2 = [
    "stays_in_week_nights",
    "previous_cancellations",
    "previous_bookings_not_canceled",
    "booking_changes",
    "days_in_waiting_list",
    "total_of_special_requests",
    "hotel_City Hotel",
    "meal_BB",
    "meal_FB",
    "meal_HB",
    "country_DEU",
    "country_ESP",
    "country_FRA",
    "country_GBR",
    "country_PRT",
    "market_segment_Corporate",
    "market_segment_Direct",
    "market_segment_Groups",
    "market_segment_TA/TO",
    "deposit_type_Non Refund",
    "customer_type_Transient",
    "tempmax",
    "tempmin",
    "temp",
    "windgust",
    "conditions_Partially cloudy"
]

# %%
df = df_train_sc[features_2]
df['is_canceled'] = y_train
corr = df.corr()
corr.style.background_gradient(cmap='coolwarm').format(precision=3)
# Out:
# <style type="text/css">
# #T_48f84_row0_col0, #T_48f84_row1_col1, #T_48f84_row2_col2, #T_48f84_row3_col3, #T_48f84_row4_col4, #T_48f84_row5_col5, #T_48f84_row6_col6, #T_48f84_row7_col7, #T_48f84_row8_col8, #T_48f84_row9_col9, #T_48f84_row10_col10, #T_48f84_row11_col11, #T_48f84_row12_col12, #T_48f84_row13_col13, #T_48f84_row14_col14, #T_48f84_row15_col15, #T_48f84_row16_col16, #T_48f84_row17_col17, #T_48f84_row18_col18, #T_48f84_row19_col19, #T_48f84_row20_col20, #T_48f84_row21_col21, #T_48f84_row22_col22, #T_48f84_row23_col23, #T_48f84_row24_col24, #T_48f84_row25_col25, #T_48f84_row26_col26 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_48f84_row0_col1, #T_48f84_row2_col23, #T_48f84_row3_col23, #T_48f84_row4_col1, #T_48f84_row5_col4, #T_48f84_row6_col8, #T_48f84_row14_col5, #T_48f84_row20_col8, #T_48f84_row22_col24 {
#   background-color: #4a63d3;
#   color: #f1f1f1;
# }
# #T_48f84_row0_col2, #T_48f84_row0_col19, #T_48f84_row3_col25, #T_48f84_row3_col26, #T_48f84_row7_col4, #T_48f84_row7_col26, #T_48f84_row10_col3, #T_48f84_row10_col4, #T_48f84_row10_col24, #T_48f84_row11_col3, #T_48f84_row11_col23, #T_48f84_row13_col3, #T_48f84_row13_col23, #T_48f84_row16_col21, #T_48f84_row16_col25, #T_48f84_row17_col2, #T_48f84_row17_col23, #T_48f84_row18_col25, #T_48f84_row25_col1 {
#   background-color: #5470de;
#   color: #f1f1f1;
# }
# #T_48f84_row0_col3, #T_48f84_row5_col15, #T_48f84_row15_col11, #T_48f84_row17_col13, #T_48f84_row19_col12, #T_48f84_row25_col21, #T_48f84_row25_col26, #T_48f84_row26_col15 {
#   background-color: #799cf8;
#   color: #f1f1f1;
# }
# #T_48f84_row0_col4, #T_48f84_row5_col22, #T_48f84_row10_col2, #T_48f84_row12_col26, #T_48f84_row15_col24, #T_48f84_row23_col0 {
#   background-color: #5a78e4;
#   color: #f1f1f1;
# }
# #T_48f84_row0_col5, #T_48f84_row0_col15, #T_48f84_row2_col11, #T_48f84_row3_col0, #T_48f84_row13_col5, #T_48f84_row14_col2, #T_48f84_row18_col0, #T_48f84_row21_col12, #T_48f84_row23_col5, #T_48f84_row23_col26 {
#   background-color: #82a6fb;
#   color: #f1f1f1;
# }
# #T_48f84_row0_col6, #T_48f84_row0_col10, #T_48f84_row10_col13, #T_48f84_row14_col20, #T_48f84_row16_col3, #T_48f84_row17_col12, #T_48f84_row24_col13, #T_48f84_row26_col8 {
#   background-color: #7093f3;
#   color: #f1f1f1;
# }
# #T_48f84_row0_col7, #T_48f84_row1_col17, #T_48f84_row2_col14, #T_48f84_row5_col9, #T_48f84_row25_col17 {
#   background-color: #aac7fd;
#   color: #000000;
# }
# #T_48f84_row0_col8, #T_48f84_row0_col14, #T_48f84_row4_col19, #T_48f84_row6_col21, #T_48f84_row12_col13, #T_48f84_row22_col10, #T_48f84_row24_col10 {
#   background-color: #6a8bef;
#   color: #f1f1f1;
# }
# #T_48f84_row0_col9, #T_48f84_row25_col9 {
#   background-color: #bbd1f8;
#   color: #000000;
# }
# #T_48f84_row0_col11, #T_48f84_row12_col5, #T_48f84_row22_col5 {
#   background-color: #84a7fc;
#   color: #f1f1f1;
# }
# #T_48f84_row0_col12, #T_48f84_row3_col11, #T_48f84_row6_col24, #T_48f84_row12_col15, #T_48f84_row14_col19, #T_48f84_row17_col8, #T_48f84_row18_col26, #T_48f84_row20_col13 {
#   background-color: #8badfd;
#   color: #000000;
# }
# #T_48f84_row0_col13, #T_48f84_row8_col11, #T_48f84_row13_col15, #T_48f84_row15_col17, #T_48f84_row21_col11, #T_48f84_row26_col20 {
#   background-color: #89acfd;
#   color: #000000;
# }
# #T_48f84_row0_col16, #T_48f84_row2_col9, #T_48f84_row9_col16, #T_48f84_row10_col20, #T_48f84_row12_col9 {
#   background-color: #abc8fd;
#   color: #000000;
# }
# #T_48f84_row0_col17, #T_48f84_row3_col20, #T_48f84_row5_col11, #T_48f84_row8_col14, #T_48f84_row25_col14 {
#   background-color: #9dbdff;
#   color: #000000;
# }
# #T_48f84_row0_col18 {
#   background-color: #ccd9ed;
#   color: #000000;
# }
# #T_48f84_row0_col20, #T_48f84_row1_col14, #T_48f84_row2_col20, #T_48f84_row10_col7, #T_48f84_row12_col7, #T_48f84_row13_col7, #T_48f84_row24_col7, #T_48f84_row26_col14 {
#   background-color: #adc9fd;
#   color: #000000;
# }
# #T_48f84_row0_col21, #T_48f84_row2_col0, #T_48f84_row3_col24, #T_48f84_row4_col3, #T_48f84_row4_col23, #T_48f84_row10_col23, #T_48f84_row11_col4, #T_48f84_row12_col3, #T_48f84_row13_col25, #T_48f84_row15_col4, #T_48f84_row15_col21, #T_48f84_row16_col0, #T_48f84_row18_col8, #T_48f84_row19_col5, #T_48f84_row20_col21, #T_48f84_row25_col3 {
#   background-color: #516ddb;
#   color: #f1f1f1;
# }
# #T_48f84_row0_col22, #T_48f84_row4_col22, #T_48f84_row8_col22, #T_48f84_row12_col1, #T_48f84_row13_col1, #T_48f84_row20_col22 {
#   background-color: #465ecf;
#   color: #f1f1f1;
# }
# #T_48f84_row0_col23, #T_48f84_row2_col21, #T_48f84_row2_col26, #T_48f84_row3_col21, #T_48f84_row6_col23, #T_48f84_row7_col3, #T_48f84_row8_col21, #T_48f84_row8_col23, #T_48f84_row9_col1, #T_48f84_row11_col25, #T_48f84_row11_col26, #T_48f84_row12_col23, #T_48f84_row16_col4, #T_48f84_row16_col24, #T_48f84_row24_col3 {
#   background-color: #4f69d9;
#   color: #f1f1f1;
# }
# #T_48f84_row0_col24, #T_48f84_row2_col3, #T_48f84_row5_col8, #T_48f84_row5_col25, #T_48f84_row12_col2, #T_48f84_row12_col24, #T_48f84_row13_col2, #T_48f84_row16_col2, #T_48f84_row18_col24, #T_48f84_row19_col25, #T_48f84_row20_col14, #T_48f84_row21_col0, #T_48f84_row21_col2 {
#   background-color: #5977e3;
#   color: #f1f1f1;
# }
# #T_48f84_row0_col25, #T_48f84_row1_col4, #T_48f84_row1_col21, #T_48f84_row2_col4, #T_48f84_row2_col19, #T_48f84_row3_col4, #T_48f84_row4_col21, #T_48f84_row7_col0, #T_48f84_row7_col1, #T_48f84_row11_col6, #T_48f84_row11_col21, #T_48f84_row12_col21, #T_48f84_row13_col19, #T_48f84_row17_col3, #T_48f84_row17_col21, #T_48f84_row18_col23, #T_48f84_row19_col22 {
#   background-color: #5572df;
#   color: #f1f1f1;
# }
# #T_48f84_row0_col26, #T_48f84_row3_col15, #T_48f84_row3_col18, #T_48f84_row21_col17, #T_48f84_row22_col20, #T_48f84_row26_col7 {
#   background-color: #a1c0ff;
#   color: #000000;
# }
# #T_48f84_row1_col0, #T_48f84_row8_col19, #T_48f84_row9_col22, #T_48f84_row19_col2, #T_48f84_row20_col6, #T_48f84_row21_col8, #T_48f84_row24_col2 {
#   background-color: #5b7ae5;
#   color: #f1f1f1;
# }
# #T_48f84_row1_col2 {
#   background-color: #e4d9d2;
#   color: #000000;
# }
# #T_48f84_row1_col3, #T_48f84_row5_col26, #T_48f84_row7_col6, #T_48f84_row7_col24, #T_48f84_row7_col25, #T_48f84_row8_col6, #T_48f84_row12_col19, #T_48f84_row12_col25, #T_48f84_row15_col5, #T_48f84_row20_col23, #T_48f84_row22_col1 {
#   background-color: #506bda;
#   color: #f1f1f1;
# }
# #T_48f84_row1_col5, #T_48f84_row7_col5, #T_48f84_row14_col1, #T_48f84_row16_col13, #T_48f84_row20_col19, #T_48f84_row26_col13 {
#   background-color: #7396f5;
#   color: #f1f1f1;
# }
# #T_48f84_row1_col6, #T_48f84_row19_col6 {
#   background-color: #7a9df8;
#   color: #f1f1f1;
# }
# #T_48f84_row1_col7, #T_48f84_row14_col9, #T_48f84_row18_col9, #T_48f84_row20_col7 {
#   background-color: #b7cff9;
#   color: #000000;
# }
# #T_48f84_row1_col8, #T_48f84_row3_col2, #T_48f84_row4_col5, #T_48f84_row6_col0, #T_48f84_row7_col10, #T_48f84_row8_col0, #T_48f84_row8_col25, #T_48f84_row19_col8, #T_48f84_row23_col19, #T_48f84_row24_col19, #T_48f84_row26_col25 {
#   background-color: #6485ec;
#   color: #f1f1f1;
# }
# #T_48f84_row1_col9, #T_48f84_row1_col15, #T_48f84_row5_col7, #T_48f84_row7_col14, #T_48f84_row11_col20, #T_48f84_row12_col16, #T_48f84_row21_col16, #T_48f84_row25_col16, #T_48f84_row25_col18 {
#   background-color: #b3cdfb;
#   color: #000000;
# }
# #T_48f84_row1_col10, #T_48f84_row5_col21, #T_48f84_row8_col5, #T_48f84_row9_col5, #T_48f84_row15_col19, #T_48f84_row16_col10, #T_48f84_row17_col6, #T_48f84_row19_col4, #T_48f84_row22_col6 {
#   background-color: #6788ee;
#   color: #f1f1f1;
# }
# #T_48f84_row1_col11, #T_48f84_row3_col12, #T_48f84_row6_col10, #T_48f84_row9_col26, #T_48f84_row16_col12, #T_48f84_row21_col5, #T_48f84_row22_col26 {
#   background-color: #81a4fb;
#   color: #f1f1f1;
# }
# #T_48f84_row1_col12, #T_48f84_row2_col5, #T_48f84_row2_col12, #T_48f84_row7_col12, #T_48f84_row9_col13, #T_48f84_row10_col11, #T_48f84_row17_col11, #T_48f84_row19_col11, #T_48f84_row21_col6, #T_48f84_row21_col13, #T_48f84_row22_col13, #T_48f84_row23_col13 {
#   background-color: #7da0f9;
#   color: #f1f1f1;
# }
# #T_48f84_row1_col13, #T_48f84_row2_col13, #T_48f84_row3_col5, #T_48f84_row6_col5, #T_48f84_row7_col13, #T_48f84_row12_col11, #T_48f84_row15_col12, #T_48f84_row25_co

# %%
vif = pd.Series([variance_inflation_factor(corr.values, i) for i in range(corr.shape[1])], index=df.columns)
vif
# Out:
# stays_in_week_nights                 1.56
# previous_cancellations               2.75
# previous_bookings_not_canceled       3.53
# booking_changes                      1.21
# days_in_waiting_list                 1.12
# total_of_special_requests            1.74
# hotel_City Hotel                    57.05
# meal_BB                              6.02
# meal_FB                              1.56
# meal_HB                              5.50
# country_DEU                          1.56
# country_ESP                          2.93
# country_FRA                          2.31
# country_GBR                          2.14
# country_PRT                          9.84
# market_segment_Corporate           150.64
# market_segment_Direct              282.17
# market_segment_Groups              222.15
# market_segment_TA/TO               631.09
# deposit_type_Non Refund              2.40
# customer_type_Transient              4.73
# tempmax                          19992.32
# tempmin                          13517.95
# temp                             65489.57
# windgust                             1.57
# conditions_Partially cloudy          5.94
# is_canceled                          3.16
# dtype: float64

# %%
df_2 = df.drop(columns=["tempmax",
                        "tempmin"])
corr = df_2.corr()
vif = pd.Series([variance_inflation_factor(corr.values, i) for i in range(corr.shape[1])], index=df_2.columns)
vif
# Out:
# stays_in_week_nights               1.52
# previous_cancellations             2.70
# previous_bookings_not_canceled     3.49
# booking_changes                    1.20
# days_in_waiting_list               1.12
# total_of_special_requests          1.72
# hotel_City Hotel                   2.97
# meal_BB                            6.02
# meal_FB                            1.55
# meal_HB                            5.48
# country_DEU                        1.56
# country_ESP                        2.89
# country_FRA                        2.30
# country_GBR                        2.12
# country_PRT                        9.80
# market_segment_Corporate         150.46
# market_segment_Direct            282.06
# market_segment_Groups            221.64
# market_segment_TA/TO             630.65
# deposit_type_Non Refund            2.30
# customer_type_Transient            4.66
# temp                               1.16
# windgust                           1.30
# conditions_Partially cloudy        1.15
# is_canceled                        2.68
# dtype: float64

# %%
# Temperatura máxima y mínima están altamente correlacionadas con la temperatura.
features_3 = [
    "stays_in_week_nights",
    "previous_cancellations",
    "previous_bookings_not_canceled",
    "booking_changes",
    "days_in_waiting_list",
    "total_of_special_requests",
    "hotel_City Hotel",
    "meal_BB",
    "meal_FB",
    "meal_HB",
    "country_DEU",
    "country_ESP",
    "country_FRA",
    "country_GBR",
    "country_PRT",
    "market_segment_Corporate",
    "market_segment_Direct",
    "market_segment_Groups",
    "market_segment_TA/TO",
    "deposit_type_Non Refund",
    "customer_type_Transient",
    "temp",
    "windgust",
    "conditions_Partially cloudy"
]

# %%
X_train_sc = df_train_sc[features_3]
y_train = train_data['is_canceled']
X_test_sc = df_test_sc[features_3]
y_test = test_data['is_canceled']
log_reg = sm.Logit(y_train, X_train_sc).fit()
print(log_reg.summary())
# Out:
# Optimization terminated successfully.
#          Current function value: 0.565021
#          Iterations 9
#                            Logit Regression Results
# ==============================================================================
# Dep. Variable:            is_canceled   No. Observations:                19208
# Model:                          Logit   Df Residuals:                    19184
# Method:                           MLE   Df Model:                           23
# Date:                Mon, 18 Dec 2023   Pseudo R-squ.:                  0.1848
# Time:                        17:12:03   Log-Likelihood:                -10853.
# converged:                       True   LL-Null:                       -13314.
# Covariance Type:            nonrobust   LLR p-value:                     0.000
# ==================================================================================================
#                                      coef    std err          z      P>|z|      [0.025      0.975]
# --------------------------------------------------------------------------------------------------
# stays_in_week_nights               0.5299      0.021     25.558      0.000       0.489       0.571
# previous_cancellations             0.3640      0.035     10.375      0.000       0.295       0.433
# previous_bookings_not_canceled    -0.6126      0.057    -10.734      0.000      -0.724      -0.501
# booking_changes                   -0.1904      0.018    -10.587      0.000      -0.226      -0.155
# days_in_waiting_list               0.3197      0.097      3.296      0.001       0.130       0.510
# total_of_special_requests         -0.1858      0.017    -10.828      0.000      -0.219      -0.152
# hotel_City Hotel                   0.4644      0.019     24.967      0.000       0.428       0.501
# meal_BB                           -0.0185      0.020     -0.924      0.355      -0.058       0.021
# meal_FB                            0.0719      0.019      3.750      0.000       0.034       0.109
# meal_HB                            0.0933      0.021      4.441      0.000       0.052       0.135
# country_DEU                       -0.0854      0.016     -5.192      0.000      -0.118      -0.053
# country_ESP                       -0.0899      0.018     -4.903      0.000      -0.126      -0.054
# country_FRA                       -0.1012      0.017     -5.835      0.000      -0.135      -0.067
# country_GBR                       -0.0157      0.017     -0.917      0.359      -0.049       0.018
# country_PRT                        0.3848      0.022     17.160      0.000       0.341       0.429
# market_segment_Corporate           0.0357      0.038      0.948      0.343      -0.038       0.109
# market_segment_Direct              0.0936      0.047      1.996      0.046       0.002       0.185
# market_segment_Groups              0.6171      0.042     14.624      0.000       0.534       0.700
# market_segment_TA/TO               0.6184      0.059     10.531      0.000       0.503       0.733
# deposit_type_Non Refund            0.4887      0.043     11.389      0.000       0.405       0.573
# customer_type_Transient            0.1012      0.020      4.997      0.000       0.062       0.141
# temp                               0.1744      0.017     10.527      0.000       0.142       0.207
# windgust                          -0.0259      0.017     -1.531      0.126      -0.059       0.007
# conditions_Partially cloudy        0.0288      0.017      1.731      0.083      -0.004       0.061
# ==================================================================================================

# %%
# Las dos feautres con alto P-value son precip y conditions_Partially cloudy. De momento seguiremos sin eliminar precip. 
features_4 = [
    "stays_in_week_nights",
    "previous_cancellations",
    "previous_bookings_not_canceled",
    "booking_changes",
    "days_in_waiting_list",
    "total_of_special_requests",
    "hotel_City Hotel",
    "meal_FB",
    "meal_HB",
    "country_DEU",
    "country_ESP",
    "country_FRA",
    "country_PRT",
    "market_segment_Groups",
    "market_segment_TA/TO",
    "deposit_type_Non Refund",
    "customer_type_Transient",
    "temp",
    "conditions_Partially cloudy"
]

# %%
from lazypredict.Supervised import LazyClassifier
from sklearn.model_selection import train_test_split

X_train_sc = df_train_sc[features_4]
y_train = train_data['is_canceled']
X_test_sc = df_test_sc[features_4]
y_test = test_data['is_canceled']

# clf = LazyClassifier(verbose=0, ignore_warnings=True, custom_metric=None)
# models, predictions = clf.fit(X_train, X_test, y_train, y_test)

# print(models)

# %%
# Entrenamiento modelo con precipitacion


model = xgb.XGBClassifier()
model.fit(X_train_sc, y_train)
# Out:
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, device=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric=None, feature_types=None,
#               gamma=None, grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=None, max_bin=None,
#               max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=None, max_leaves=None,
#               min_child_weight=None, missing=nan, monotone_constraints=None,
#               multi_strategy=None, n_estimators=None, n_jobs=None,
#               num_parallel_tree=None, random_state=None, ...)

# %%
y_pred = model.predict(X_test_sc)

# %%
cm = confusion_matrix(y_test, y_pred)
cm_display = ConfusionMatrixDisplay(cm).plot()

# %%
# Ahora provamos lo mismo sin las dos unicas variables de meteorologia que nos han sobrevivido
features_4 = [
    "stays_in_week_nights",
    "previous_cancellations",
    "previous_bookings_not_canceled",
    "booking_changes",
    "days_in_waiting_list",
    "total_of_special_requests",
    "hotel_City Hotel",
    "meal_FB",
    "meal_HB",
    "country_DEU",
    "country_ESP",
    "country_FRA",
    "country_PRT",
    "market_segment_Groups",
    "market_segment_TA/TO",
    "deposit_type_Non Refund",
    "customer_type_Transient"
]

# %%
X_train_sc = df_train_sc[features_4]
y_train = train_data['is_canceled']
X_test_sc = df_test_sc[features_4]
y_test = test_data['is_canceled']

model = xgb.XGBClassifier()
model.fit(X_train_sc, y_train)
y_pred = model.predict(X_test_sc)

# %%
cm = confusion_matrix(y_test, y_pred)
cm_display = ConfusionMatrixDisplay(cm).plot()

# %% [markdown]
# Viendo los resultados que estamos obteniendo, aunque sea sin optimizar los hiperparámetros, podemos concluir que las variables meteorológicas no mejoran el modelo de machine learning y no hace falta incluirlas. Por tanto, no es necesario separar el dataset.

# %% [markdown]
# ### Dataset entero

# %%
# Repetimos el mismo procedimiento de seleccion de features con el mismo criterio que anteriormente.

# %%
reservas = pd.read_csv("Data/hotel_bookings_clean.csv")
reservas['arrival_date'] = pd.to_datetime(reservas['arrival_date'])
reservas['reservation_status_date'] = pd.to_datetime(reservas['reservation_status_date'])
reservas['children'] = reservas['children'].astype(int)

# %%
reservas['arrival_date_year'] = reservas['arrival_date'].dt.year
reservas['arrival_date_day/month'] = reservas['arrival_date'].dt.strftime('%d/%m')

# %%
dias_por_mes_1 = [
    31, 28, 31, 30, 31, 30, 31, 31, 30, 31, 30, 31
]
dias_por_mes_2 = [
    31, 29, 31, 30, 31, 30, 31, 31, 30, 31, 30, 31
]

def dia_del_año(dia_mes, anio): 
    dia, mes = dia_mes.split('/')
    dia = int(dia)
    mes = int(mes)
    if anio%4 == 0: 
        return dia + sum(dias_por_mes_2[:mes-1])
    else:
        return dia + sum(dias_por_mes_1[:mes-1])

dias_mes = list(reservas['arrival_date_day/month'])
anios = list(reservas['arrival_date_year'])

dias_x = []
dias_y = []
for dia, anio in zip(dias_mes,anios):
    if anio%4 == 0:
        angulo = 2*np.pi * dia_del_año(dia,anio)/366
        dias_x.append(np.cos(angulo))
        dias_y.append(np.sin(angulo))
    else:
        angulo = 2*np.pi * dia_del_año(dia,anio)/365
        dias_x.append(np.cos(angulo))
        dias_y.append(np.sin(angulo))
reservas['dia_x'] = dias_x
reservas['dia_y'] = dias_y
reservas.drop(columns=["arrival_date_day/month","arrival_date_year"],inplace=True)

# %%
reservas = pd.get_dummies(reservas)
reservas.iloc[0], reservas.shape
# Out:
# (is_canceled                                         0
#  lead_time                                         342
#  stays_in_weekend_nights                             0
#  stays_in_week_nights                                0
#  adults                                              2
#  children                                            0
#  babies                                              0
#  is_repeated_guest                                   0
#  previous_cancellations                              0
#  previous_bookings_not_canceled                      0
#  booking_changes                                     3
#  days_in_waiting_list                                0
#  total_of_special_requests                           0
#  reservation_status_date           2015-07-01 00:00:00
#  arrival_date                      2015-07-01 00:00:00
#  dia_x                                           -1.00
#  dia_y                                            0.01
#  hotel_City Hotel                                    0
#  hotel_Resort Hotel                                  1
#  meal_BB                                             1
#  meal_FB                                             0
#  meal_HB                                             0
#  meal_No_meal                                        0
#  country_DEU                                         0
#  country_ESP                                         0
#  country_FRA                                         0
#  country_GBR                                         0
#  country_PRT                                         1
#  country_otros                                       0
#  market_segment_Aviation                             0
#  market_segment_Complementary                        0
#  market_segment_Corporate                            0
#  market_segment_Direct                               1
#  market_segment_Groups                               0
#  market_segment_TA/TO                                0
#  distribution_channel_Corporate                      0
#  distribution_channel_Direct                         1
#  distribution_channel_GDS                            0
#  distribution_channel_TA/TO                          0
#  deposit_type_No Deposit                             1
#  deposit_type_Non Refund                             0
#  deposit_type_Refundable                             0
#  customer_type_Contract                              0
#  customer_type_Group                                 0
#  customer_type_Transient                             1
#  customer_type_Transient-Party                       0
#  Name: 0, dtype: object,
#  (118898, 46))

# %%
features = [
    "lead_time",
    "stays_in_weekend_nights",
    "stays_in_week_nights",
    "adults",
    "children",
    "babies",
    "is_repeated_guest",
    "previous_cancellations",
    "previous_bookings_not_canceled",
    "booking_changes",
    "days_in_waiting_list",
    "total_of_special_requests",
    "dia_x",
    "dia_y",
    "hotel_City Hotel",
    "meal_BB",
    "meal_FB",
    "meal_HB",
    "country_DEU",
    "country_ESP",
    "country_FRA",
    "country_GBR",
    "country_PRT",
    "market_segment_Aviation",
    "market_segment_Corporate",
    "market_segment_Direct",
    "market_segment_Groups",
    "market_segment_TA/TO",
    "distribution_channel_Corporate",
    "distribution_channel_Direct",
    "distribution_channel_TA/TO",
    "deposit_type_Non Refund",
    "deposit_type_Refundable",
    "customer_type_Contract",
    "customer_type_Group",
    "customer_type_Transient"
]

# %%
X = reservas[features]
y = reservas['is_canceled']
train_data = reservas[(reservas['arrival_date'] >= pd.Timestamp('2015-07-01')) & 
                              (reservas['arrival_date'] <= pd.Timestamp('2017-06-30'))]
test_data = reservas[(reservas['arrival_date'] >= pd.Timestamp('2017-07-01')) & 
                             (reservas['arrival_date'] <= pd.Timestamp('2017-08-31'))]

# Balancear los datos
#Contar la frecuencia de cada clase y obtener la frecuencia mínima entre las clases
frecuencia_minima = train_data['is_canceled'].value_counts().min()

#Crear una muestra ponderada según la frecuencia de la clase minoritaria
train_data = train_data.groupby('is_canceled').apply(lambda x: x.sample(frac=frecuencia_minima / len(x))).reset_index(drop=True)

X_train = train_data[features]
y_train = train_data['is_canceled']
X_test = test_data[features]
y_test = test_data['is_canceled']
print(X_train.shape, y_train.shape, X_test.shape, y_test.shape)
# Out:
# (80706, 36) (80706,) (10238, 36) (10238,)

# %%
# Escalar los datos

from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
scaler.fit(X_train)
X_train_sc = scaler.transform(X_train)
X_test_sc = scaler.transform(X_test)

# %%
X_train_sc
# Out:
# array([[-0.32826325, -0.91386915,  0.80990318, ..., -0.1895103 ,
#         -0.06427044,  0.57049197],
#        [ 2.24547836,  1.0962619 ,  1.34082612, ..., -0.1895103 ,
#         -0.06427044,  0.57049197],
#        [-0.47481082, -0.91386915,  0.27898025, ..., -0.1895103 ,
#         -0.06427044,  0.57049197],
#        ...,
#        [-0.4290147 , -0.91386915, -0.78286562, ..., -0.1895103 ,
#         -0.06427044,  0.57049197],
#        [-0.47481082, -0.91386915, -0.25194269, ..., -0.1895103 ,
#         -0.06427044,  0.57049197],
#        [ 0.02894644, -0.91386915, -0.25194269, ..., -0.1895103 ,
#         -0.06427044, -1.75287306]])

# %%
df_train_sc = pd.DataFrame(X_train_sc, columns=X_train.columns)
df_test_sc = pd.DataFrame(X_test_sc, columns=X_test.columns)

# %%
model = xgb.XGBClassifier()
model.fit(X_train_sc, y_train)
feature_importances = model.feature_importances_
feature_names = X.columns
feature_importance_dict = dict(zip(feature_names, feature_importances))
sorted_feature_importance = dict(sorted(feature_importance_dict.items(), key=lambda x: x[1], reverse=True))
for feature, importance in sorted_feature_importance.items():
    print(f'Feature: {feature}, Importance: {importance}')
# Out:
# Feature: deposit_type_Non Refund, Importance: 0.6928089261054993
# Feature: customer_type_Transient, Importance: 0.04264575242996216
# Feature: previous_cancellations, Importance: 0.033171333372592926
# Feature: country_PRT, Importance: 0.02970357984304428
# Feature: market_segment_TA/TO, Importance: 0.017626143991947174
# Feature: total_of_special_requests, Importance: 0.014117153361439705
# Feature: country_FRA, Importance: 0.011287123896181583
# Feature: previous_bookings_not_canceled, Importance: 0.011027167551219463
# Feature: country_DEU, Importance: 0.009918305091559887
# Feature: hotel_City Hotel, Importance: 0.009845072403550148
# Feature: customer_type_Contract, Importance: 0.00900866836309433
# Feature: lead_time, Importance: 0.008901236578822136
# Feature: distribution_channel_Direct, Importance: 0.00870135985314846
# Feature: booking_changes, Importance: 0.008647865615785122
# Feature: country_GBR, Importance: 0.008272802457213402
# Feature: market_segment_Groups, Importance: 0.007454475853592157
# Feature: children, Importance: 0.007194368168711662
# Feature: distribution_channel_TA/TO, Importance: 0.006304507609456778
# Feature: days_in_waiting_list, Importance: 0.00576427485793829
# Feature: distribution_channel_Corporate, Importance: 0.004807759542018175
# Feature: meal_HB, Importance: 0.004593617748469114
# Feature: stays_in_weekend_nights, Importance: 0.004451566841453314
# Feature: market_segment_Direct, Importance: 0.004247276112437248
# Feature: stays_in_week_nights, Importance: 0.004130521789193153
# Feature: meal_BB, Importance: 0.0040547773241996765
# Feature: country_ESP, Importance: 0.0040153618901968
# Feature: dia_x, Importance: 0.003836067859083414
# Feature: adults, Importance: 0.0034672992769628763
# Feature: is_repeated_guest, Importance: 0.0033369064331054688
# Feature: babies, Importance: 0.0032764379866421223
# Feature: dia_y, Importance: 0.0032198436092585325
# Feature: market_segment_Corporate, Importance: 0.0028188538271933794
# Feature: meal_FB, Importance: 0.002417515264824033
# Feature: market_segment_Aviation, Importance: 0.0020439480431377888
# Feature: customer_type_Group, Importance: 0.0018140737665817142
# Feature: deposit_type_Refundable, Importance: 0.0010681122075766325

# %%
df = df_train_sc[features]
df['is_canceled'] = y_train
corr = df.corr()
corr[corr.is_canceled.abs()<0.02].index
# Out:
# Index(['stays_in_weekend_nights', 'children', 'dia_y', 'meal_BB',
#        'market_segment_Aviation', 'deposit_type_Refundable'],
#       dtype='object')

# %%
features_2 = [
    "lead_time",
    "adults",
    "babies",
    "is_repeated_guest",
    "previous_cancellations",
    "previous_bookings_not_canceled",
    "booking_changes",
    "days_in_waiting_list",
    "total_of_special_requests",
    "hotel_City Hotel",
    "meal_FB",
    "meal_HB",
    "country_DEU",
    "country_ESP",
    "country_FRA",
    "country_GBR",
    "country_PRT",
    "market_segment_Corporate",
    "market_segment_Direct",
    "market_segment_Groups",
    "market_segment_TA/TO",
    "distribution_channel_Corporate",
    "distribution_channel_Direct",
    "distribution_channel_TA/TO",
    "deposit_type_Non Refund",
    "customer_type_Contract",
    "customer_type_Transient"
]

# %%
df = df_train_sc[features_2]
df['is_canceled'] = y_train
corr = df.corr()
corr.style.background_gradient(cmap='coolwarm').format(precision=3)
# Out:
# <style type="text/css">
# #T_1ec53_row0_col0, #T_1ec53_row1_col1, #T_1ec53_row2_col2, #T_1ec53_row3_col3, #T_1ec53_row4_col4, #T_1ec53_row5_col5, #T_1ec53_row6_col6, #T_1ec53_row7_col7, #T_1ec53_row8_col8, #T_1ec53_row9_col9, #T_1ec53_row10_col10, #T_1ec53_row11_col11, #T_1ec53_row12_col12, #T_1ec53_row13_col13, #T_1ec53_row14_col14, #T_1ec53_row15_col15, #T_1ec53_row16_col16, #T_1ec53_row17_col17, #T_1ec53_row18_col18, #T_1ec53_row19_col19, #T_1ec53_row20_col20, #T_1ec53_row21_col21, #T_1ec53_row22_col22, #T_1ec53_row23_col23, #T_1ec53_row24_col24, #T_1ec53_row25_col25, #T_1ec53_row26_col26, #T_1ec53_row27_col27 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_1ec53_row0_col1, #T_1ec53_row6_col15, #T_1ec53_row12_col8 {
#   background-color: #90b2fe;
#   color: #000000;
# }
# #T_1ec53_row0_col2, #T_1ec53_row8_col4, #T_1ec53_row17_col0 {
#   background-color: #3f53c6;
#   color: #f1f1f1;
# }
# #T_1ec53_row0_col3, #T_1ec53_row4_col7, #T_1ec53_row14_col10, #T_1ec53_row27_col12 {
#   background-color: #5470de;
#   color: #f1f1f1;
# }
# #T_1ec53_row0_col4, #T_1ec53_row5_col12, #T_1ec53_row7_col8, #T_1ec53_row10_col3, #T_1ec53_row13_col15, #T_1ec53_row15_col11, #T_1ec53_row16_col7, #T_1ec53_row16_col11, #T_1ec53_row19_col4, #T_1ec53_row20_col27, #T_1ec53_row22_col1, #T_1ec53_row24_col10, #T_1ec53_row27_col4 {
#   background-color: #6f92f3;
#   color: #f1f1f1;
# }
# #T_1ec53_row0_col5, #T_1ec53_row6_col27, #T_1ec53_row11_col10 {
#   background-color: #516ddb;
#   color: #f1f1f1;
# }
# #T_1ec53_row0_col6, #T_1ec53_row0_col10, #T_1ec53_row1_col10, #T_1ec53_row2_col9, #T_1ec53_row14_col5, #T_1ec53_row15_col5, #T_1ec53_row17_col9, #T_1ec53_row21_col10, #T_1ec53_row24_col13, #T_1ec53_row25_col6 {
#   background-color: #5e7de7;
#   color: #f1f1f1;
# }
# #T_1ec53_row0_col7, #T_1ec53_row1_col0, #T_1ec53_row3_col8, #T_1ec53_row7_col27, #T_1ec53_row8_col13, #T_1ec53_row8_col17, #T_1ec53_row11_col15, #T_1ec53_row17_col20, #T_1ec53_row18_col8, #T_1ec53_row23_col14, #T_1ec53_row23_col26 {
#   background-color: #8badfd;
#   color: #000000;
# }
# #T_1ec53_row0_col8, #T_1ec53_row6_col2, #T_1ec53_row7_col6, #T_1ec53_row10_col11, #T_1ec53_row11_col26, #T_1ec53_row14_col12, #T_1ec53_row18_col24 {
#   background-color: #6180e9;
#   color: #f1f1f1;
# }
# #T_1ec53_row0_col9, #T_1ec53_row18_col6, #T_1ec53_row27_col1 {
#   background-color: #81a4fb;
#   color: #f1f1f1;
# }
# #T_1ec53_row0_col11, #T_1ec53_row4_col0, #T_1ec53_row4_col5, #T_1ec53_row8_col19, #T_1ec53_row9_col12, #T_1ec53_row9_col25, #T_1ec53_row10_col25, #T_1ec53_row11_col0, #T_1ec53_row11_col12, #T_1ec53_row25_col24, #T_1ec53_row26_col14 {
#   background-color: #89acfd;
#   color: #000000;
# }
# #T_1ec53_row0_col12, #T_1ec53_row2_col24, #T_1ec53_row4_col15, #T_1ec53_row5_col24, #T_1ec53_row14_col1, #T_1ec53_row18_col25, #T_1ec53_row21_col24, #T_1ec53_row22_col13 {
#   background-color: #7da0f9;
#   color: #f1f1f1;
# }
# #T_1ec53_row0_col13, #T_1ec53_row5_col1, #T_1ec53_row11_col4, #T_1ec53_row12_col16, #T_1ec53_row13_col9, #T_1ec53_row14_col27, #T_1ec53_row21_col11, #T_1ec53_row22_col2, #T_1ec53_row24_col12, #T_1ec53_row25_col10, #T_1ec53_row26_col10 {
#   background-color: #5673e0;
#   color: #f1f1f1;
# }
# #T_1ec53_row0_col14, #T_1ec53_row7_col3, #T_1ec53_row9_col7, #T_1ec53_row13_col6, #T_1ec53_row13_col14, #T_1ec53_row13_col24, #T_1ec53_row16_col10, #T_1ec53_row18_col20, #T_1ec53_row20_col18, #T_1ec53_row21_col8, #T_1ec53_row24_col11, #T_1ec53_row25_col3, #T_1ec53_row26_col5 {
#   background-color: #6b8df0;
#   color: #f1f1f1;
# }
# #T_1ec53_row0_col15, #T_1ec53_row2_col16, #T_1ec53_row11_col17, #T_1ec53_row11_col25, #T_1ec53_row18_col17, #T_1ec53_row24_col25 {
#   background-color: #8fb1fe;
#   color: #000000;
# }
# #T_1ec53_row0_col16, #T_1ec53_row4_col21, #T_1ec53_row6_col20, #T_1ec53_row7_col18, #T_1ec53_row9_col24, #T_1ec53_row13_col19, #T_1ec53_row19_col27, #T_1ec53_row27_col20 {
#   background-color: #bbd1f8;
#   color: #000000;
# }
# #T_1ec53_row0_col17, #T_1ec53_row1_col12, #T_1ec53_row4_col8, #T_1ec53_row4_col14, #T_1ec53_row6_col16, #T_1ec53_row8_col3, #T_1ec53_row8_col6, #T_1ec53_row17_col14, #T_1ec53_row17_col15, #T_1ec53_row19_col9, #T_1ec53_row21_col6 {
#   background-color: #779af7;
#   color: #f1f1f1;
# }
# #T_1ec53_row0_col18, #T_1ec53_row2_col8, #T_1ec53_row4_col17, #T_1ec53_row7_col0, #T_1ec53_row11_col21, #T_1ec53_row18_col21, #T_1ec53_row23_col25 {
#   background-color: #a1c0ff;
#   color: #000000;
# }
# #T_1ec53_row0_col19 {
#   background-color: #f6bfa6;
#   color: #000000;
# }
# #T_1ec53_row0_col20, #T_1ec53_row3_col20, #T_1ec53_row6_col17, #T_1ec53_row7_col16, #T_1ec53_row9_col27, #T_1ec53_row13_col21, #T_1ec53_row14_col21, #T_1ec53_row24_col18, #T_1ec53_row24_col21, #T_1ec53_row25_col21, #T_1ec53_row26_col8 {
#   background-color: #a7c5fe;
#   color: #000000;
# }
# #T_1ec53_row0_col21, #T_1ec53_row1_col25, #T_1ec53_row2_col26, #T_1ec53_row5_col8, #T_1ec53_row16_col25, #T_1ec53_row20_col1, #T_1ec53_row20_col12, #T_1ec53_row22_col17, #T_1ec53_row26_col17 {
#   background-color: #92b4fe;
#   color: #000000;
# }
# #T_1ec53_row0_col22, #T_1ec53_row14_col19, #T_1ec53_row15_col21, #T_1ec53_row17_col19, #T_1ec53_row19_col21, #T_1ec53_row27_col22 {
#   background-color: #afcafc;
#   color: #000000;
# }
# #T_1ec53_row0_col23 {
#   background-color: #ecd3c5;
#   color: #000000;
# }
# #T_1ec53_row0_col24, #T_1ec53_row8_col20, #T_1ec53_row24_col27 {
#   background-color: #edd2c3;
#   color: #000000;
# }
# #T_1ec53_row0_col25, #T_1ec53_row1_col8, #T_1ec53_row27_col18 {
#   background-color: #a2c1ff;
#   color: #000000;
# }
# #T_1ec53_row0_col26, #T_1ec53_row11_col3, #T_1ec53_row12_col6, #T_1ec53_row13_col10, #T_1ec53_row14_col3, #T_1ec53_row14_col6, #T_1ec53_row15_col3, #T_1ec53_row15_col14, #T_1ec53_row19_col1, #T_1ec53_row19_col3, #T_1ec53_row21_col12, #T_1ec53_row22_col24, #T_1ec53_row24_col1, #T_1ec53_row27_col10 {
#   background-color: #6788ee;
#   color: #f1f1f1;
# }
# #T_1ec53_row0_col27 {
#   background-color: #cfdaea;
#   color: #000000;
# }
# #T_1ec53_row1_col2, #T_1ec53_row1_col5, #T_1ec53_row3_col7, #T_1ec53_row11_col2, #T_1ec53_row20_col3 {
#   background-color: #4b64d5;
#   color: #f1f1f1;
# }
# #T_1ec53_row1_col3, #T_1ec53_row1_col7, #T_1ec53_row5_col7, #T_1ec53_row7_col4, #T_1ec53_row8_col10, #T_1ec53_row13_col16, #T_1ec53_row14_col7 {
#   background-color: #506bda;
#   color: #f1f1f1;
# }
# #T_1ec53_row1_col4, #T_1ec53_row2_col7, #T_1ec53_row9_col6, #T_1ec53_row10_col7, #T_1ec53_row12_col7, #T_1ec53_row18_col27, #T_1ec53_row22_col27 {
#   background-color: #4f69d9;
#   color: #f1f1f1;
# }
# #T_1ec53_row1_col6, #T_1ec53_row3_col10, #T_1ec53_row5_col0, #T_1ec53_row7_col10, #T_1ec53_row15_col27, #T_1ec53_row17_col10, #T_1ec53_row17_col11, #T_1ec53_row18_col2, #T_1ec53_row20_col6 {
#   background-color: #5875e1;
#   color: #f1f1f1;
# }
# #T_1ec53_row1_col9, #T_1ec53_row2_col0, #T_1ec53_row2_col5, #T_1ec53_row4_col9, #T_1ec53_row6_col1, #T_1ec53_row6_col24, #T_1ec53_row9_col5, #T_1ec53_row13_col12, #T_1ec53_row14_col11, #T_1ec53_row14_col24, #T_1ec53_row15_col13, #T_1ec53_row17_col27, #T_1ec53_row18_col11, #T_1ec53_row22_col20, #T_1ec53_row27_col11, #T_1ec53_row27_col13 {
#   background-color: #6384eb;
#   color: #f1f1f1;
# }
# #T_1ec53_row1_col11, #T_1ec53_row15_col1, #T_1ec53_row16_col26, #T_1ec53_row24_col7, #T_1ec53_row25_col14 {
#   background-color: #799cf8;
#   color: #f1f1f1;
# }
# #T_1ec53_row1_col13, #T_1ec53_row6_col25, #T_1ec53_row7_col25, #T_1ec53_row12_col26, #T_1ec53_row14_col25, #T_1ec53_row19_col17, #T_1ec53_row21_col15, #T_1ec53_row22_col8, #T_1ec53_row23_col15, #T_1ec53_row26_col1 {
#   background-color: #85a8fc;
#   color: #f1f1f1;
# }
# #T_1ec53_row1_col14, #T_1ec53_row1_col15, #T_1ec53_row3_col26, #T_1ec53_row4_col10, #T_1ec53_row8_col1 {
#   background-color: #8db0fe;
#   color: #000000;
# }
# #T_1ec53_row1_col16, #T_1ec53_row10_col1, #T_1ec53_row12_col1, #T_1ec53_row13_col11, #T_1ec53_row26_col3 {
#   background-color: #7396f5;
#   color: #f1f1f1;
# }
# #T_1ec53_row1_col17, #T_1ec53_row4_col12, #T_1ec53_row10_col0, #T_1ec53_row14_col15, #T_1ec53_row18_col12, #T_1ec53_row19_col7, #T_1ec53_row19_col13, #T_1ec53_row20_col11, #T_1ec53_row25_col11, #T_1ec53_row26_col12 {
#   background-color: #6c8ff1;
#   color: #f1f1f1;
# }
# #T_1ec53_row1_col18

# %%
df = df_train_sc[features_2]
df['is_canceled'] = y_train
corr = df.corr()
# vif_data = pd.DataFrame()
# vif_data["Variable"] = X.columns
# vif_data["VIF"] = [variance_inflation_factor(X.values, i) for i in range(X.shape[1])]
vif = pd.Series([variance_inflation_factor(corr.values, i) for i in range(corr.shape[1])], index=df.columns)
vif
# Out:
# lead_time                            5.41
# adults                               2.27
# babies                               1.11
# is_repeated_guest                    4.27
# previous_cancellations               1.44
# previous_bookings_not_canceled       2.66
# booking_changes                      1.37
# days_in_waiting_list                 1.31
# total_of_special_requests            2.88
# hotel_City Hotel                     4.47
# meal_FB                              1.35
# meal_HB                              1.58
# country_DEU                          2.03
# country_ESP                          2.46
# country_FRA                          2.47
# country_GBR                          3.14
# country_PRT                         15.63
# market_segment_Corporate           804.94
# market_segment_Direct             1875.51
# market_segment_Groups             4776.58
# market_segment_TA/TO              8218.59
# distribution_channel_Corporate   16259.69
# distribution_channel_Direct      38924.54
# distribution_channel_TA/TO       59720.23
# deposit_type_Non Refund             19.76
# customer_type_Contract               2.35
# customer_type_Transient              8.28
# is_canceled                          5.58
# dtype: float64

# %%
df_2 = df.drop(columns=["distribution_channel_Corporate",
                        "distribution_channel_Direct",
                        "distribution_channel_TA/TO"])
corr = df_2.corr()
vif = pd.Series([variance_inflation_factor(corr.values, i) for i in range(corr.shape[1])], index=df_2.columns)
vif
# Out:
# lead_time                           5.37
# adults                              1.68
# babies                              1.10
# is_repeated_guest                   3.82
# previous_cancellations              1.39
# previous_bookings_not_canceled      2.57
# booking_changes                     1.31
# days_in_waiting_list                1.31
# total_of_special_requests           2.60
# hotel_City Hotel                    2.71
# meal_FB                             1.31
# meal_HB                             1.54
# country_DEU                         2.02
# country_ESP                         2.33
# country_FRA                         2.42
# country_GBR                         3.03
# country_PRT                        14.98
# market_segment_Corporate          471.91
# market_segment_Direct            1013.28
# market_segment_Groups            3634.35
# market_segment_TA/TO             4595.67
# deposit_type_Non Refund            19.68
# customer_type_Contract              2.18
# customer_type_Transient             7.45
# is_canceled                         5.32
# dtype: float64

# %%
features_3 = [
    "lead_time",
    "adults",
    "babies",
    "is_repeated_guest",
    "previous_cancellations",
    "previous_bookings_not_canceled",
    "booking_changes",
    "days_in_waiting_list",
    "total_of_special_requests",
    "hotel_City Hotel",
    "meal_FB",
    "meal_HB",
    "country_DEU",
    "country_ESP",
    "country_FRA",
    "country_GBR",
    "country_PRT",
    "market_segment_Corporate",
    "market_segment_Direct",
    "market_segment_Groups",
    "market_segment_TA/TO",
    "deposit_type_Non Refund",
    "customer_type_Contract",
    "customer_type_Transient"
]

# %%
X_train_sc = df_train_sc[features_3]
y_train = train_data['is_canceled']
X_test_sc = df_test_sc[features_3]
y_test = test_data['is_canceled']
log_reg = sm.Logit(y_train, X_train_sc).fit()
print(log_reg.summary())
# Out:
# Optimization terminated successfully.
#          Current function value: 0.467199
#          Iterations 9
#                            Logit Regression Results
# ==============================================================================
# Dep. Variable:            is_canceled   No. Observations:                80706
# Model:                          Logit   Df Residuals:                    80682
# Method:                           MLE   Df Model:                           23
# Date:                Mon, 18 Dec 2023   Pseudo R-squ.:                  0.3260
# Time:                        17:12:06   Log-Likelihood:                -37706.
# converged:                       True   LL-Null:                       -55941.
# Covariance Type:            nonrobust   LLR p-value:                     0.000
# ==================================================================================================
#                                      coef    std err          z      P>|z|      [0.025      0.975]
# --------------------------------------------------------------------------------------------------
# lead_time                          0.5680      0.013     45.189      0.000       0.543       0.593
# adults                             0.1861      0.012     15.479      0.000       0.163       0.210
# babies                             0.0007      0.010      0.072      0.943      -0.019       0.020
# is_repeated_guest                 -0.1822      0.014    -13.011      0.000      -0.210      -0.155
# previous_cancellations             1.3238      0.052     25.376      0.000       1.222       1.426
# previous_bookings_not_canceled    -0.5886      0.050    -11.820      0.000      -0.686      -0.491
# booking_changes                   -0.2209      0.011    -19.374      0.000      -0.243      -0.199
# days_in_waiting_list              -0.1082      0.010    -10.415      0.000      -0.129      -0.088
# total_of_special_requests         -0.4292      0.010    -43.026      0.000      -0.449      -0.410
# hotel_City Hotel                   0.2735      0.010     28.015      0.000       0.254       0.293
# meal_FB                            0.0375      0.010      3.796      0.000       0.018       0.057
# meal_HB                           -0.0401      0.010     -4.167      0.000      -0.059      -0.021
# country_DEU                       -0.2009      0.010    -20.690      0.000      -0.220      -0.182
# country_ESP                        0.0159      0.009      1.719      0.086      -0.002       0.034
# country_FRA                       -0.1846      0.010    -19.053      0.000      -0.204      -0.166
# country_GBR                       -0.1401      0.010    -14.110      0.000      -0.160      -0.121
# country_PRT                        0.6060      0.012     49.237      0.000       0.582       0.630
# market_segment_Corporate           0.0762      0.025      3.106      0.002       0.028       0.124
# market_segment_Direct              0.0179      0.034      0.531      0.595      -0.048       0.084
# market_segment_Groups              0.4866      0.048     10.124      0.000       0.392       0.581
# market_segment_TA/TO               0.6558      0.054     12.077      0.000       0.549       0.762
# deposit_type_Non Refund            0.5990      0.017     34.374      0.000       0.565       0.633
# customer_type_Contract            -0.0097      0.012     -0.820      0.412      -0.033       0.014
# customer_type_Transient            0.5748      0.013     44.159      0.000       0.549       0.600
# ==================================================================================================

# %%
features_4 = [
    "lead_time",
    "adults",
    "is_repeated_guest",
    "previous_cancellations",
    "previous_bookings_not_canceled",
    "booking_changes",
    "days_in_waiting_list",
    "total_of_special_requests",
    "hotel_City Hotel",
    "meal_FB",
    "meal_HB",
    "country_DEU",
    "country_FRA",
    "country_GBR",
    "country_PRT",
    "market_segment_Corporate",
    "market_segment_Groups",
    "market_segment_TA/TO",
    "deposit_type_Non Refund",
    "customer_type_Transient"
]

# %%
X_train_sc = df_train_sc[features_4]
y_train = train_data['is_canceled']
X_test_sc = df_test_sc[features_4]
y_test = test_data['is_canceled']

model = xgb.XGBClassifier()
model.fit(X_train_sc, y_train)
y_pred = model.predict(X_test_sc)

# %%
cm = confusion_matrix(y_test, y_pred)
cm_display = ConfusionMatrixDisplay(cm).plot()

# %%
from sklearn.metrics import classification_report
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.77      0.78      0.77      6438
#            1       0.61      0.60      0.61      3800
#
#     accuracy                           0.71     10238
#    macro avg       0.69      0.69      0.69     10238
# weighted avg       0.71      0.71      0.71     10238

# %%
y_pred_train = model.predict(X_train_sc)
print(classification_report(y_train, y_pred_train))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.80      0.86      0.83     40353
#            1       0.85      0.78      0.82     40353
#
#     accuracy                           0.82     80706
#    macro avg       0.83      0.82      0.82     80706
# weighted avg       0.83      0.82      0.82     80706

# %%
# PCA

from sklearn.decomposition import PCA
pca = PCA(.99)
pca.fit(X_train_sc)
X_pca_train = pca.transform(X_train_sc)
X_pca_test = pca.transform(X_test_sc)

# %%
len(features_4)
# Out:
# 20

# %%
print(pca.explained_variance_ratio_)
# Out:
# [0.14973281 0.09807957 0.07482453 0.06378491 0.05854288 0.05602414
#  0.05342439 0.05126349 0.04822794 0.04709578 0.04387637 0.04169778
#  0.03895443 0.03616731 0.03429244 0.03098648 0.0287166  0.02130086
#  0.01507717]

# %%
len(pca.explained_variance_ratio_)
# Out:
# 19

# %%
model = xgb.XGBClassifier()
model.fit(X_pca_train, y_train)
y_pred = model.predict(X_pca_test)

# %%
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.76      0.77      0.76      6438
#            1       0.60      0.58      0.59      3800
#
#     accuracy                           0.70     10238
#    macro avg       0.68      0.67      0.68     10238
# weighted avg       0.70      0.70      0.70     10238

# %%
y_pred_train = model.predict(X_pca_train)
print(classification_report(y_train, y_pred_train))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.81      0.88      0.85     40353
#            1       0.87      0.80      0.83     40353
#
#     accuracy                           0.84     80706
#    macro avg       0.84      0.84      0.84     80706
# weighted avg       0.84      0.84      0.84     80706

# %% [markdown]
# ### Optimizacion de hiperparámetros

# %%
from sklearn.model_selection import RandomizedSearchCV
import scipy.stats as stats

param_dist = {
    'learning_rate': stats.uniform(0.01,0.2),
    'max_depth': stats.randint(3, 10),
    'subsample': stats.uniform(0.5, 1),
    'colsample_bytree': stats.uniform(0.5,1),
    'colsample_bylevel': stats.uniform(0.5,1),
    'colsample_bynode': stats.uniform(0.5,1),
    'n_estimators':stats.randint(50, 200)
}

random_search = RandomizedSearchCV(model, param_distributions=param_dist, n_iter=1000, cv=5, scoring='accuracy',verbose=1)
random_search.fit(X_train_sc, y_train)

print("Mejor conjunto de hiperparametros: ", random_search.best_params_)
print("Mejor accuracy: ", random_search.best_score_)
# Out:
# Fitting 5 folds for each of 1000 candidates, totalling 5000 fits
# Mejor conjunto de hiperparametros:  {'colsample_bylevel': 0.8091218301059356, 'colsample_bynode': 0.9221811441276574, 'colsample_bytree': 0.9355780801271562, 'learning_rate': 0.1503375535843294, 'max_depth': 8, 'n_estimators': 178, 'subsample': 0.7618354368056748}
# Mejor accuracy:  0.8164696164916577

# %%
# Optimizacion Bayesiana (https://medium.com/@rithpansanga/optimizing-xgboost-a-guide-to-hyperparameter-tuning-77b6e48e289d)

from hyperopt import fmin, tpe, hp, STATUS_OK
from sklearn.metrics import accuracy_score

# %%
# Acotamos los hiperparámetros en base a los resultados obtenidos en la RandomizedSearchCV
space = {
    'learning_rate': hp.loguniform('learning_rate', -1.3, -0.6), # Aplicamos logaritmo al maximo y al minimo para definir el rango
    'subsample': hp.uniform('subsample', 0.6, 0.9),
    'colsample_bytree': hp.quniform('colsample_bytree',0.8,1,0.05),
    'colsample_bylevel': hp.quniform('colsample_bylevel',0.6,1,0.05),
    'colsample_bynode': hp.quniform('colsample_bynode',0.8,1,0.05)
}
    
def objective(params):
    xgb_model = xgb.XGBClassifier(**params)
    xgb_model.fit(X_train_sc, y_train)
    y_pred = xgb_model.predict(X_test_sc)
    score = accuracy_score(y_test, y_pred)
    return {'loss': -score, 'status': STATUS_OK}

best_params = fmin(objective, space, algo=tpe.suggest, max_evals=1000)
print("Best set of hyperparameters: ", best_params)
# Out:
# 100%|██████████| 1000/1000 [07:25<00:00,  2.24trial/s, best loss: -0.7182066809923813]
# Best set of hyperparameters:  {'colsample_bylevel': 0.9500000000000001, 'colsample_bynode': 0.8, 'colsample_bytree': 0.8, 'learning_rate': 0.28841810710611226, 'subsample': 0.8684439079467414}

# %%
from sklearn.ensemble import BaggingClassifier

# %%
# Creamos el clasificador base con los hiperparámetros:
best_params['max_depth'] = 8 
clasificador_base = xgb.XGBClassifier(**best_params)

# %%
# Creamos el clasificador Bagging
clasificador_bagging = BaggingClassifier(clasificador_base, n_estimators=178, random_state=42)

# %%
# Entrenamos
clasificador_bagging.fit(X_train_sc, y_train)
# Out:
# BaggingClassifier(estimator=XGBClassifier(base_score=None, booster=None,
#                                           callbacks=None,
#                                           colsample_bylevel=0.9500000000000001,
#                                           colsample_bynode=0.8,
#                                           colsample_bytree=0.8, device=None,
#                                           early_stopping_rounds=None,
#                                           enable_categorical=False,
#                                           eval_metric=None, feature_types=None,
#                                           gamma=None, grow_policy=None,
#                                           importance_type=None,
#                                           interaction_constraints=None,
#                                           learning_rate=0.28841810710611226,
#                                           max_bin=None, max_cat_threshold=None,
#                                           max_cat_to_onehot=None,
#                                           max_delta_step=None, max_depth=8,
#                                           max_leaves=None,
#                                           min_child_weight=None, missing=nan,
#                                           monotone_constraints=None,
#                                           multi_strategy=None,
#                                           n_estimators=None, n_jobs=None,
#                                           num_parallel_tree=None,
#                                           random_state=None, ...),
#                   n_estimators=178, random_state=42)

# %%
y_pred = clasificador_bagging.predict(X_test_sc)

# %%
y_pred_train = clasificador_bagging.predict(X_train_sc)

# %%
print(f'accuracy en train:{accuracy_score(y_train,y_pred_train)}\naccuracy en test: {accuracy_score(y_test,y_pred)}')
# Out:
# accuracy en train:0.8385250167273809
# accuracy en test: 0.7086344989255714

# %% [markdown]
# ### Exportacion del modelo

# %%
from joblib import dump
dump(clasificador_bagging, 'modelo_proyecto.joblib')
# Out:
# ['modelo_proyecto.joblib']

# %% [markdown]
# ### Entrenar el modelo con el dataset completo

# %%
reservas = pd.read_csv("Data/hotel_bookings_clean.csv")
reservas = pd.get_dummies(reservas)
X = reservas[features_4]
y = reservas['is_canceled']
frecuencia_minima = reservas['is_canceled'].value_counts().min()
reservas = reservas.groupby('is_canceled').apply(lambda x: x.sample(frac=frecuencia_minima / len(x))).reset_index(drop=True)

# %%
scaler = StandardScaler()
scaler.fit(X)
X_sc = scaler.transform(X)

# %%
# Hiperparametros
param_dist = {
    'learning_rate': stats.uniform(0.01,0.2),
    'max_depth': stats.randint(3, 10),
    'subsample': stats.uniform(0.5, 1),
    'colsample_bytree': stats.uniform(0.5,1),
    'colsample_bylevel': stats.uniform(0.5,1),
    'colsample_bynode': stats.uniform(0.5,1),
    'n_estimators':stats.randint(50, 200)
}

random_search = RandomizedSearchCV(model, param_distributions=param_dist, n_iter=1000, cv=5, scoring='accuracy',verbose=1)
random_search.fit(X_train_sc, y_train)

print("Mejor conjunto de hiperparametros: ", random_search.best_params_)
print("Mejor accuracy: ", random_search.best_score_)
# Out:
# Fitting 5 folds for each of 1000 candidates, totalling 5000 fits
# Mejor conjunto de hiperparametros:  {'colsample_bylevel': 0.6802712770473117, 'colsample_bynode': 0.9277478639798314, 'colsample_bytree': 0.864767956127546, 'learning_rate': 0.20462620315935748, 'max_depth': 9, 'n_estimators': 147, 'subsample': 0.8550046971419236}
# Mejor accuracy:  0.8179689101612141

# %%
space = {
    'learning_rate': hp.loguniform('learning_rate', -1.3, -0.7), # Aplicamos logaritmo al maximo y al minimo para definir el rango
    'subsample': hp.uniform('subsample', 0.7, 0.95),
    'colsample_bytree': hp.quniform('colsample_bytree',0.7,1,0.05),
    'colsample_bylevel': hp.quniform('colsample_bylevel',0.5,0.9,0.05),
    'colsample_bynode': hp.quniform('colsample_bynode',0.8,1,0.05)
}
    
def objective(params):
    xgb_model = xgb.XGBClassifier(**params)
    xgb_model.fit(X_train_sc, y_train)
    y_pred = xgb_model.predict(X_test_sc)
    score = accuracy_score(y_test, y_pred)
    return {'loss': -score, 'status': STATUS_OK}

best_params = fmin(objective, space, algo=tpe.suggest, max_evals=1000)
print("Best set of hyperparameters: ", best_params)
# Out:
# 100%|██████████| 1000/1000 [07:19<00:00,  2.28trial/s, best loss: -0.7195741355733541]
# Best set of hyperparameters:  {'colsample_bylevel': 0.65, 'colsample_bynode': 0.8500000000000001, 'colsample_bytree': 0.75, 'learning_rate': 0.2725984287425052, 'subsample': 0.8892444859148654}

# %%
best_params['max_depth'] = 9
clasificador_base = xgb.XGBClassifier(**best_params)
clasificador_bagging = BaggingClassifier(clasificador_base, n_estimators=147, random_state=42)

# %%
clasificador_bagging.fit(X_sc, y)
# Out:
# BaggingClassifier(estimator=XGBClassifier(base_score=None, booster=None,
#                                           callbacks=None,
#                                           colsample_bylevel=0.65,
#                                           colsample_bynode=0.8500000000000001,
#                                           colsample_bytree=0.75, device=None,
#                                           early_stopping_rounds=None,
#                                           enable_categorical=False,
#                                           eval_metric=None, feature_types=None,
#                                           gamma=None, grow_policy=None,
#                                           importance_type=None,
#                                           interaction_constraints=None,
#                                           learning_rate=0.2725984287425052,
#                                           max_bin=None, max_cat_threshold=None,
#                                           max_cat_to_onehot=None,
#                                           max_delta_step=None, max_depth=9,
#                                           max_leaves=None,
#                                           min_child_weight=None, missing=nan,
#                                           monotone_constraints=None,
#                                           multi_strategy=None,
#                                           n_estimators=None, n_jobs=None,
#                                           num_parallel_tree=None,
#                                           random_state=None, ...),
#                   n_estimators=147, random_state=42)

# %%
dump(clasificador_bagging, 'modelo_proyecto_entero.joblib')
# Out:
# ['modelo_proyecto_entero.joblib']
